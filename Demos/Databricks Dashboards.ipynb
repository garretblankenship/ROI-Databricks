# %% [markdown]
# # Databricks Dashboards: Complete Guide 📊
#
# Welcome! This follow-along demo will teach you how to build interactive dashboards in Databricks using Lakeview Dashboards.
#
# ---
#
# ## 🎯 What You'll Learn
#
# By the end of this demo, you will be able to:
#
# 1. ✅ Create and configure dashboards
# 2. ✅ Add data sources and create datasets
# 3. ✅ Build visualizations (pie charts, bar charts, line charts, counters)
# 4. ✅ Use AI to generate visualizations
# 5. ✅ Implement filtering (cross-filtering, global, page, widget)
# 6. ✅ Create parameterized datasets
# 7. ✅ Use custom calculations and formulas
# 8. ✅ Enable AI forecasting
# 9. ✅ Publish and schedule dashboard refreshes
# 10. ✅ Configure dashboard settings
#
# ---
#
# ## 📍 What are Databricks Dashboards?
#
# **Databricks Dashboards** (Lakeview) are interactive, visual reports built on your lakehouse data.
#
# **Key features:**
# * 📊 **Visual analytics** - Charts, graphs, counters
# * 🤖 **AI-powered** - Generate visualizations with natural language
# * 🎯 **Interactive filters** - Cross-filtering, global filters
# * 🔄 **Auto-refresh** - Scheduled updates
# * 💾 **Multiple data sources** - Combine different tables
# * 🧠 **Custom calculations** - Create calculated fields
# * 🔮 **AI forecasting** - Predict future trends
#
# ---
#
# ## 📊 Demo Scenario: Wanderbricks Booking Analytics
#
# You'll build a dashboard for **Wanderbricks** (a vacation rental platform):
#
# **Data sources:**
# * `samples.wanderbricks.bookings` - Booking transactions
# * `samples.wanderbricks.properties` - Property listings
# * `samples.wanderbricks.reviews` - Customer reviews
# * `samples.wanderbricks.users` - User information
#
# **Dashboard sections:**
# * Booking revenue and trends
# * Property type analysis
# * Review ratings
# * Custom metrics and forecasts
#
# ---
#
# ## 📝 Important Note
#
# **This demo uses the Databricks Dashboards interface (Lakeview), not notebooks.**
#
# To follow along:
# 1. Navigate to **Dashboards** in the left sidebar
# 2. Follow the step-by-step instructions
# 3. Try each feature as you go
# 4. Complete the challenges
#
# ---
#
# **Let's build your first dashboard!** 🚀

# %% [markdown]
# ## Part 1: Creating Your Dashboard 🏗️
#
# Let's start by creating a new dashboard and setting it up.
#
# ---

# %% [markdown]
# ### 🎯 Step 1: Create a New Dashboard
#
# **Follow these steps:**
#
# 1. Click **"Dashboards"** in the left sidebar
# 2. Click the **"Create Dashboard"** button (top-right)
# 3. A new blank dashboard opens in edit mode
# 4. You'll see:
#    * Empty canvas in the center
#    * **"+ Add"** button to add visualizations
#    * **"Data"** tab to manage data sources
#    * **"Publish"** button (top-right)
#
# **Dashboard interface:**
# * **Canvas** - Where you place visualizations
# * **Data tab** - Manage datasets and queries
# * **Edit mode** - Build and modify dashboard
# * **View mode** - Published dashboard for viewers
#
# ✅ **Checkpoint:** You should now have a blank dashboard open
#
# ---

# %% [markdown]
# ### ✏️ Step 2: Rename Your Dashboard
#
# **Follow these steps:**
#
# 1. Look at the **top-left** of the dashboard
# 2. You'll see "Untitled Dashboard" or similar
# 3. **Click on the title** to edit it
# 4. Type: **"Wanderbricks Booking Insights"**
# 5. Press **Enter** to save
#
# **Naming best practices:**
# * Use descriptive names
# * Include purpose or department
# * Be specific ("Q4 Sales" not "Dashboard 1")
#
# ✅ **Checkpoint:** Dashboard title is now "Wanderbricks Booking Insights"
#
# ---

# %% [markdown]
# ### 📝 Step 3: Rename the Dashboard Page
#
# **Follow these steps:**
#
# Dashboards can have multiple pages (like tabs):
#
# 1. Look at the **bottom** of the dashboard (or top, depending on UI)
# 2. You'll see page tabs (default: "Page 1" or "New Page")
# 3. **Right-click** on the page tab
# 4. Select **"Rename"** from the menu
# 5. Type: **"Booking Overview"**
# 6. Press **Enter**
#
# **Alternative method:**
# * Click the page tab
# * Look for a pencil/edit icon
# * Click to rename
#
# **Multiple pages:**
# * Dashboards can have multiple pages
# * Each page can have different visualizations
# * Use pages to organize related content
#
# ✅ **Checkpoint:** Page is now named "Booking Overview"
#
# ---

# %% [markdown]
# ### 💾 Step 4: Add Data Sources
#
# **Follow these steps:**
#
# 1. Click the **"Data"** tab (usually top-left or top-center)
# 2. You'll see the data sources panel
# 3. Click **"+ Add"** or **"Add dataset"**
# 4. A dialog opens to create a new dataset
#
# **Add first dataset (Bookings):**
# 1. In the dataset dialog:
#    * **Name:** "bookings"
#    * **SQL Query:**
#    ```sql
#    SELECT
#      booking_id,
#      user_id,
#      property_id,
#      check_in,
#      check_out,
#      guests_count,
#      total_amount,
#      status,
#      created_at,
#      DATEDIFF(check_out, check_in) AS nights,
#      YEAR(created_at) AS booking_year,
#      MONTH(created_at) AS booking_month,
#      DATE(created_at) AS booking_date
#    FROM samples.wanderbricks.bookings
#    WHERE status = 'confirmed'
#    ```
# 2. Click **"Save"** or **"Create"**
#
# **Add second dataset (Reviews):**
# 1. Click **"+ Add"** again
# 2. Configure:
#    * **Name:** "reviews"
#    * **SQL Query:**
#    ```sql
#    SELECT
#      review_id,
#      booking_id,
#      property_id,
#      user_id,
#      rating,
#      comment,
#      created_at,
#      DATE(created_at) AS review_date
#    FROM samples.wanderbricks.reviews
#    WHERE is_deleted = false
#    ```
# 3. Click **"Save"**
#
# ✅ **Checkpoint:** You now have 2 datasets: "bookings" and "reviews"
#
# ---
#
# **💡 Tip:** Pre-calculate fields (like nights, booking_date) in datasets for easier visualization

# %% [markdown]
# ## Part 2: Adding Basic Visualizations 📊
#
# Let's add text and charts to your dashboard.
#
# ---

# %% [markdown]
# ### 📝 Step 5: Add a Text Box Header
#
# **Follow these steps:**
#
# 1. Click the **"+ Add"** button on the dashboard canvas
# 2. Select **"Text box"** from the menu
# 3. A text editor appears
# 4. Type: **"Monthly Booking Report"**
# 5. **Format the text:**
#    * Highlight the text
#    * Use the formatting toolbar:
#      - Make it **bold**
#      - Increase font size (Heading 1 or Heading 2)
#      - Center align (optional)
# 6. Click outside the text box or click **"Done"**
# 7. **Resize and position:**
#    * Drag the text box to the top of the dashboard
#    * Resize by dragging corners
#    * Make it span the full width
#
# **Text box features:**
# * Markdown support
# * Multiple font sizes
# * Bold, italic, underline
# * Alignment options
# * Background colors
#
# ✅ **Checkpoint:** Dashboard has a header text box at the top
#
# ---
#
# **💡 Tip:** Use text boxes for titles, descriptions, and instructions

# %% [markdown]
# ### 🍰 Step 6: Create a Pie Chart - Bookings by Status
#
# **Follow these steps:**
#
# 1. Click **"+ Add"** on the canvas
# 2. Select **"Visualization"**
# 3. A visualization configuration panel opens
#
# **Configure the visualization:**
#
# 4. **Dataset:** Select "bookings"
#
# 5. **Visualization type:** Select **"Pie chart"**
#
# 6. **Configure fields:**
#    * **Angle (Value):** Drag `booking_id` and use **COUNT**
#    * **Color (Category):** Drag `status`
#    * **Tooltip:** Add `total_amount` with **SUM**
#
# 7. **Settings:**
#    * Enable **"Show labels"**
#    * Enable **"Show legend"**
#
# 8. **Title:** "Bookings by Status"
#
# 9. Click **"Save"** or **"Apply"**
#
# 10. **Position the chart:**
#     * Drag it below the text box
#     * Resize to appropriate size
#
# **What you'll see:**
# * Pie chart showing distribution of booking statuses
# * Each slice represents a status (confirmed, pending, cancelled)
# * Hover shows count and total amount
#
# ✅ **Checkpoint:** Pie chart showing bookings by status
#
# ---
#
# **💡 Tip:** Pie charts work best with 3-7 categories

# %% [markdown]
# ### 🎯 **Challenge 1: Create a Bar Chart**
#
# **Your task:**
#
# Create a bar chart showing total booking revenue by property type.
#
# **Requirements:**
# 1. Add a new visualization
# 2. Use the "bookings" dataset
# 3. Create a bar chart
# 4. X-axis: You'll need to join with properties table (or create new dataset)
# 5. Y-axis: SUM of total_amount
# 6. Title: "Revenue by Property Type"
#
# **Hint:** You may need to create a new dataset that joins bookings with properties:
# ```sql
# SELECT
#   b.booking_id,
#   b.total_amount,
#   b.created_at,
#   p.property_type,
#   p.title AS property_name
# FROM samples.wanderbricks.bookings b
# JOIN samples.wanderbricks.properties p ON b.property_id = p.property_id
# WHERE b.status = 'confirmed'
# ```
#
# **Steps:**
# 1. Go to Data tab
# 2. Add new dataset named "bookings_with_properties"
# 3. Use the query above
# 4. Create bar chart visualization
# 5. Configure: property_type (X), SUM(total_amount) (Y)
#
# ✅ **Success criteria:** Bar chart showing revenue by property type
#
# ---

# %% [markdown]
# ## Part 3: AI-Powered Features 🤖
#
# Databricks Dashboards include AI capabilities to generate visualizations and forecast trends.
#
# ---

# %% [markdown]
# ### 🤖 Step 7: Use AI to Create a Visualization
#
# **Follow these steps:**
#
# 1. Click **"+ Add"** on the canvas
# 2. Look for **"AI-generated visualization"** or **"Ask AI"** option
# 3. Click it to open the AI prompt dialog
#
# **Enter this prompt:**
# ```
# Create a line chart showing the average review rating by date
# ```
#
# 4. **AI will:**
#    * Analyze your datasets
#    * Choose the appropriate dataset (reviews)
#    * Select relevant columns (rating, created_at)
#    * Create the visualization automatically
#    * Configure axes and aggregations
#
# 5. Review the generated visualization:
#    * Check if it used the correct dataset
#    * Verify the chart type (line chart)
#    * Confirm axes are correct
#
# 6. **Customize if needed:**
#    * Click the visualization settings
#    * Adjust title, colors, or axes
#    * Add filters
#
# 7. Click **"Save"** or **"Apply"**
#
# **What AI does:**
# * Understands natural language
# * Selects appropriate dataset
# * Chooses best chart type
# * Configures aggregations
# * Sets up axes and labels
#
# ✅ **Checkpoint:** Line chart showing average rating over time
#
# ---
#
# **💡 Tip:** Be specific in your AI prompts - mention chart type, metrics, and dimensions

# %% [markdown]
# ### 🎯 **Challenge 2: AI-Generated Visualization**
#
# **Your task:**
#
# Use AI to create a visualization showing booking trends.
#
# **Prompt to try:**
# ```
# Create a line chart of total booking revenue by month
# ```
#
# **Requirements:**
# 1. Use the AI visualization feature
# 2. Enter the prompt above
# 3. Review what AI generates
# 4. Customize the title to "Monthly Booking Revenue Trend"
# 5. Adjust colors if desired
#
# **Expected result:**
# * Line chart with months on X-axis
# * Total revenue on Y-axis
# * Shows trend over time
#
# **Bonus challenge:**
# Try different prompts:
# * "Bar chart of bookings by property type"
# * "Counter showing total revenue"
# * "Pie chart of bookings by guest count"
#
# ✅ **Success criteria:** AI-generated line chart showing monthly revenue
#
# ---

# %% [markdown]
# ### 🔮 Step 8: Enable AI Forecasting
#
# **Follow these steps:**
#
# AI forecasting predicts future values based on historical trends.
#
# 1. **Create a time-series visualization first:**
#    * Add new visualization
#    * Dataset: "bookings"
#    * Type: **Line chart**
#    * X-axis: `booking_date` (or use DATE_TRUNC for weekly)
#    * Y-axis: SUM of `total_amount`
#    * Title: "Booking Revenue Over Time"
#
# 2. **Enable forecasting:**
#    * Click on the visualization to edit
#    * Look for **"Forecast"** or **"AI Forecast"** toggle
#    * **Enable** the forecast option
#
# 3. **Configure forecast settings:**
#    * **Forecast periods:** 7 (predict next 7 days/weeks)
#    * **Confidence interval:** 95% (shows prediction range)
#    * **Seasonality:** Auto-detect
#
# 4. Click **"Apply"** or **"Save"**
#
# **What you'll see:**
# * Historical data (solid line)
# * Forecasted values (dashed line)
# * Confidence interval (shaded area)
# * Future predictions based on past trends
#
# **Forecast works best with:**
# * At least 2-3 months of historical data
# * Regular patterns or trends
# * Daily or weekly aggregations
# * Numeric values (revenue, counts)
#
# ✅ **Checkpoint:** Line chart with AI forecast showing future predictions
#
# ---
#
# **💡 Tip:** Forecasting requires sufficient historical data to detect patterns

# %% [markdown]
# ### 🎯 **Challenge 3: Create Forecast Visualization**
#
# **Your task:**
#
# Create a line chart with AI forecasting for weekly bookings.
#
# **Requirements:**
# 1. Create a new dataset with weekly aggregation:
#    ```sql
#    SELECT
#      DATE_TRUNC('week', created_at) AS week,
#      COUNT(*) AS booking_count,
#      SUM(total_amount) AS weekly_revenue
#    FROM samples.wanderbricks.bookings
#    WHERE status = 'confirmed'
#    GROUP BY DATE_TRUNC('week', created_at)
#    ORDER BY week
#    ```
# 2. Name dataset: "weekly_bookings"
# 3. Create line chart:
#    * X-axis: week
#    * Y-axis: booking_count
# 4. Enable AI forecast
# 5. Set forecast periods to 4 (next 4 weeks)
# 6. Title: "Weekly Booking Forecast"
#
# **Expected result:**
# * Line chart showing historical weekly bookings
# * Dashed line showing predicted next 4 weeks
# * Confidence interval shading
#
# ✅ **Success criteria:** Working forecast visualization
#
# ---

# %% [markdown]
# ## Part 4: Interactive Filtering 🎯
#
# Filters make dashboards interactive by letting users focus on specific data.
#
# **Filter types:**
# * **Cross-filtering** - Click a chart to filter others
# * **Global filters** - Apply to entire dashboard
# * **Page filters** - Apply to current page only
# * **Widget filters** - Apply to specific visualization
#
# ---

# %% [markdown]
# ### 🔗 Step 9: Enable Cross-Filtering
#
# **What is cross-filtering?**
# Click on one visualization to filter other visualizations on the same dataset.
#
# **Follow these steps:**
#
# 1. **Create two visualizations from the same dataset:**
#
#    **Visualization 1: Pie chart**
#    * Dataset: "bookings_with_properties"
#    * Type: Pie chart
#    * Angle: COUNT of booking_id
#    * Color: property_type
#    * Title: "Bookings by Property Type"
#
#    **Visualization 2: Bar chart**
#    * Dataset: "bookings_with_properties" (same dataset!)
#    * Type: Bar chart
#    * X-axis: booking_month
#    * Y-axis: SUM of total_amount
#    * Title: "Monthly Revenue"
#
# 2. **Enable cross-filtering:**
#    * Click on the **pie chart** to edit
#    * Look for **"Interactions"** or **"Filtering"** settings
#    * Enable **"Cross-filter"** or **"Filter other visualizations"**
#    * Save
#
# 3. **Test cross-filtering:**
#    * Click on a slice of the pie chart (e.g., "apartment")
#    * Watch the bar chart update to show only apartment bookings
#    * Click again to clear the filter
#
# **Key requirement:**
# * Both visualizations must use the **same dataset**
# * Cross-filtering doesn't work across different datasets
#
# ✅ **Checkpoint:** Clicking pie chart filters the bar chart
#
# ---
#
# **💡 Tip:** Cross-filtering creates interactive drill-down experiences

# %% [markdown]
# ### 🌍 Step 10: Add Global Filters
#
# **What are global filters?**
# Filters that apply to ALL visualizations on ALL pages of the dashboard.
#
# **Follow these steps:**
#
# 1. Look for the **"Filters"** button or panel (usually top-right)
# 2. Click **"+ Add filter"** or **"Add global filter"**
# 3. A filter configuration dialog opens
#
# **Configure a global filter:**
#
# 4. **Filter settings:**
#    * **Name:** "Property Type"
#    * **Dataset:** "bookings_with_properties"
#    * **Column:** `property_type`
#    * **Type:** Multi-select dropdown
#    * **Default:** All selected
#
# 5. Click **"Save"** or **"Apply"**
#
# 6. A filter widget appears at the top of the dashboard
#
# **Test the global filter:**
# 1. Click the "Property Type" filter dropdown
# 2. Unselect some property types
# 3. Watch ALL visualizations update
# 4. Works across all pages
# 5. Select "All" to reset
#
# **Global filter characteristics:**
# * 🌍 Applies to entire dashboard
# * 🌍 Works on all pages
# * 🌍 Affects all visualizations using that dataset
# * 🌍 Visible to all dashboard viewers
#
# ✅ **Checkpoint:** Global filter controls all visualizations
#
# ---
#
# **💡 Tip:** Use global filters for common dimensions like date ranges, regions, or categories

# %% [markdown]
# ### 📝 Step 11: Add Page-Level Filters
#
# **What are page filters?**
# Filters that apply only to visualizations on the current page.
#
# **Follow these steps:**
#
# 1. Look for **"Page filters"** or filter settings for the current page
# 2. Click **"+ Add page filter"**
#
# **Configure a page filter:**
#
# 3. **Filter settings:**
#    * **Name:** "Booking Status"
#    * **Dataset:** "bookings"
#    * **Column:** `status`
#    * **Type:** Dropdown
#    * **Default:** "confirmed"
#
# 4. Click **"Save"**
#
# 5. Filter appears on the page (may be at top or in filter panel)
#
# **Test the page filter:**
# 1. Change the status filter
# 2. Only visualizations on THIS page update
# 3. Navigate to another page (if you have one)
# 4. Filter doesn't affect other pages
#
# **Page vs Global filters:**
#
# | Feature | Global Filter | Page Filter |
# |---------|---------------|-------------|
# | Scope | All pages | Current page only |
# | Visibility | Always visible | Page-specific |
# | Use case | Common dimensions | Page-specific filters |
# | Example | Date range, region | Specific metric filter |
#
# ✅ **Checkpoint:** Page filter affects only current page
#
# ---
#
# **💡 Tip:** Use page filters for page-specific dimensions that don't apply globally

# %% [markdown]
# ### 🎯 Step 12: Add Widget-Level Filters
#
# **What are widget filters?**
# Filters that apply to a single visualization only.
#
# **Follow these steps:**
#
# 1. **Click on a visualization** to edit it
# 2. Look for the **"Filters"** section in the configuration panel
# 3. Click **"+ Add filter"**
#
# **Configure a widget filter:**
#
# 4. **Filter settings:**
#    * **Column:** `guests_count`
#    * **Condition:** Greater than
#    * **Value:** 2
#
# 5. Click **"Apply"** or **"Save"**
#
# 6. This visualization now only shows bookings with more than 2 guests
#
# **Test the widget filter:**
# 1. This visualization shows filtered data
# 2. Other visualizations are NOT affected
# 3. Filter is invisible to viewers (applied automatically)
#
# **Widget filter use cases:**
# * Exclude outliers from specific chart
# * Show only relevant data for that metric
# * Apply business rules to specific visualization
# * Filter without affecting other charts
#
# **Filter hierarchy:**
# ```
# Widget Filter (most specific)
#     ↓
# Page Filter
#     ↓
# Global Filter (least specific)
# ```
#
# All filters combine (AND logic).
#
# ✅ **Checkpoint:** Widget filter affects only that visualization
#
# ---
#
# **💡 Tip:** Widget filters are "hidden" - viewers don't see them but data is filtered

# %% [markdown]
# ### ✅ Filtering - Key Points
#
# **Filter types comparison:**
#
# | Filter Type | Scope | Visible to Users | Use Case |
# |-------------|-------|------------------|----------|
# | **Cross-filter** | Same dataset | Interactive (click) | Drill-down analysis |
# | **Global filter** | All pages | Yes (filter widget) | Common dimensions |
# | **Page filter** | Current page | Yes (on page) | Page-specific |
# | **Widget filter** | Single viz | No (hidden) | Specific exclusions |
#
# **Setting up filters:**
# * 👉 **Cross-filter:** Enable in visualization settings
# * 👉 **Global filter:** Add from Filters panel
# * 👉 **Page filter:** Add from page settings
# * 👉 **Widget filter:** Add in visualization config
#
# **Important notes:**
# * ⚠️ Cross-filtering requires **same dataset**
# * ⚠️ Global/page filters work **across datasets**
# * ⚠️ Filters combine with AND logic
# * ⚠️ Widget filters are invisible to viewers
#
# **Best practices:**
# * ✅ Use global filters for date ranges
# * ✅ Use cross-filtering for exploration
# * ✅ Use page filters for page-specific dimensions
# * ✅ Use widget filters for data quality (exclude nulls, outliers)
#
# ---

# %% [markdown]
# ## Part 5: Parameterized Datasets 🎯
#
# Parameters in datasets make dashboards dynamic and interactive.
#
# **What are dataset parameters?**
# * Variables in dataset SQL queries
# * Users can change values via widgets
# * Filter data at the query level
# * More efficient than post-query filtering
#
# ---

# %% [markdown]
# ### 🎯 Step 13: Create a Dataset with Parameters
#
# **Follow these steps:**
#
# 1. Go to the **"Data"** tab
# 2. Click **"+ Add"** to create a new dataset
# 3. **Name:** "bookings_by_date_range"
#
# 4. **Enter this SQL query:**
# ```sql
# SELECT
#   b.booking_id,
#   b.total_amount,
#   b.guests_count,
#   b.created_at,
#   DATE(b.created_at) AS booking_date,
#   p.property_type,
#   p.title AS property_name,
#   CONCAT(u.name, ' (', u.country, ')') AS customer_info
# FROM samples.wanderbricks.bookings b
# JOIN samples.wanderbricks.properties p ON b.property_id = p.property_id
# JOIN samples.wanderbricks.users u ON b.user_id = u.user_id
# WHERE DATE(b.created_at) BETWEEN :date_range.start AND :date_range.end
#   AND b.status = 'confirmed'
# ```
#
# 5. Notice the **`:date_range.start`** and **`:date_range.end`** syntax
#    * This creates a date range parameter
#    * `:parameter_name` is the parameter syntax
#    * `.start` and `.end` for date ranges
#
# 6. Click **"Save"**
#
# 7. A **parameter widget** is automatically created!
#
# **Parameter syntax:**
# * `:param_name` - Single value parameter
# * `:date_range.start` and `:date_range.end` - Date range
# * `:param_name.min` and `:param_name.max` - Numeric range
#
# ✅ **Checkpoint:** Dataset created with date range parameter
#
# ---
#
# **💡 Tip:** Parameters filter data at the source - more efficient than filtering after query

# %% [markdown]
# ### 📊 Step 14: Create Visualization with Parameters
#
# **Follow these steps:**
#
# 1. Click **"+ Add"** → **"Visualization"**
#
# 2. **Configure:**
#    * **Dataset:** "bookings_by_date_range"
#    * **Type:** Bar chart
#    * **X-axis:** `property_type`
#    * **Y-axis:** SUM of `total_amount`
#    * **Title:** "Revenue by Property Type (Filtered)"
#
# 3. Click **"Save"**
#
# 4. **The date range parameter widget appears** on the dashboard
#
# 5. **Test the parameter:**
#    * Click the date range widget
#    * Select different date ranges
#    * Watch the bar chart update
#    * Data is filtered at the query level
#
# **Try different date ranges:**
# * Last 30 days
# * Last 90 days
# * Specific month
# * Year-to-date
#
# ✅ **Checkpoint:** Bar chart updates when you change date range parameter
#
# ---

# %% [markdown]
# ### ⚠️ Step 15: Understanding Parameters vs Filters
#
# **Important difference:**
#
# **Cross-filtering limitation with parameters:**
#
# 1. **Create two visualizations:**
#    * Viz 1: From "bookings" dataset (no parameters)
#    * Viz 2: From "bookings_by_date_range" dataset (with parameters)
#
# 2. **Try cross-filtering:**
#    * Click on Viz 1
#    * Viz 2 does NOT filter
#    * **Why?** Different datasets = no cross-filtering
#
# 3. **But global/page filters still work:**
#    * Add a global filter for property_type
#    * Both visualizations filter correctly
#    * Global filters work across datasets
#
# **Key differences:**
#
# | Feature | Parameters | Filters |
# |---------|------------|----------|
# | **Location** | In SQL query | After query runs |
# | **Efficiency** | More efficient | Less efficient |
# | **Cross-filtering** | Breaks it (different datasets) | Works |
# | **Global filters** | Still work | Works |
# | **Use case** | Date ranges, thresholds | Interactive exploration |
#
# **When to use each:**
# * **Parameters:** Date ranges, large data filtering, performance
# * **Filters:** Interactive exploration, cross-filtering, drill-down
#
# **Best practice:**
# * Use parameters for date ranges (efficient)
# * Use same non-parameterized dataset for cross-filtering
# * Use global filters for common dimensions
#
# ✅ **Checkpoint:** Understand parameter limitations with cross-filtering
#
# ---
#
# **💡 Tip:** For cross-filtering, use the same dataset; for efficiency, use parameters

# %% [markdown]
# ### 🎯 **Challenge 4: Parameterized Dashboard**
#
# **Your task:**
#
# Create a parameterized dataset and visualization with multiple parameters.
#
# **Requirements:**
#
# 1. **Create new dataset:** "bookings_filtered"
# 2. **SQL with multiple parameters:**
#    ```sql
#    SELECT
#      b.booking_id,
#      b.total_amount,
#      b.guests_count,
#      DATE(b.created_at) AS booking_date,
#      p.property_type
#    FROM samples.wanderbricks.bookings b
#    JOIN samples.wanderbricks.properties p ON b.property_id = p.property_id
#    WHERE DATE(b.created_at) BETWEEN :date_range.start AND :date_range.end
#      AND b.total_amount >= :min_amount
#      AND b.guests_count >= :min_guests
#      AND b.status = 'confirmed'
#    ```
#
# 3. **Create bar chart:**
#    * X-axis: property_type
#    * Y-axis: COUNT of booking_id
#    * Title: "Bookings by Type (Filtered)"
#
# 4. **Test parameters:**
#    * Adjust date range
#    * Change min_amount (try 500, 1000)
#    * Change min_guests (try 2, 4)
#    * Watch chart update
#
# **Expected result:**
# * Three parameter widgets on dashboard
# * Bar chart updates with parameter changes
# * Efficient filtering at query level
#
# ✅ **Success criteria:** Working parameterized visualization with 3 parameters
#
# ---

# %% [markdown]
# ## Part 6: Custom Calculations 🧠
#
# **Custom calculations** let you create new fields using formulas without modifying the dataset query.
#
# **What are custom calculations?**
# * Calculated fields created in the dashboard
# * Use existing columns in formulas
# * Support SQL expressions
# * Reusable across visualizations
#
# **Use cases:**
# * Mathematical calculations
# * Conditional logic (CASE statements)
# * String concatenation
# * Date calculations
# * Business metrics
#
# ---

# %% [markdown]
# ### 🧠 Step 16: Create a Simple Calculated Field
#
# **Follow these steps:**
#
# 1. Go to the **"Data"** tab
# 2. Select a dataset (e.g., "bookings")
# 3. Look for **"Calculations"** or **"Add calculation"** button
# 4. Click **"+ Add calculation"** or **"New field"**
#
# **Create first calculation:**
#
# 5. **Calculation settings:**
#    * **Name:** `revenue_per_night`
#    * **Formula:**
#    ```sql
#    total_amount / nights
#    ```
#    * **Description:** "Average revenue per night"
#
# 6. Click **"Save"**
#
# 7. The new field appears in the dataset!
#
# **Using the calculated field:**
#
# 8. Create a new visualization:
#    * Dataset: "bookings"
#    * Type: Bar chart
#    * X-axis: property_type
#    * Y-axis: AVG of `revenue_per_night` (your calculated field)
#    * Title: "Average Revenue per Night by Property Type"
#
# 9. The calculated field works like any other column!
#
# ✅ **Checkpoint:** Calculated field created and used in visualization
#
# ---
#
# **💡 Tip:** Calculated fields are computed on-the-fly from the dataset

# %% [markdown]
# ### 📊 Step 17: Create a CASE Statement Calculation
#
# **Follow these steps:**
#
# Create a calculated field with conditional logic:
#
# 1. In the **"Data"** tab, select your dataset
# 2. Click **"+ Add calculation"**
#
# **Create booking tier calculation:**
#
# 3. **Calculation settings:**
#    * **Name:** `booking_tier`
#    * **Formula:**
#    ```sql
#    CASE
#      WHEN total_amount < 500 THEN 'Budget'
#      WHEN total_amount >= 500 AND total_amount < 1500 THEN 'Standard'
#      WHEN total_amount >= 1500 AND total_amount < 3000 THEN 'Premium'
#      WHEN total_amount >= 3000 THEN 'Luxury'
#    END
#    ```
#    * **Description:** "Categorizes bookings by price tier"
#
# 4. Click **"Save"**
#
# **Create another calculation:**
#
# 5. Click **"+ Add calculation"** again
# 6. **Calculation settings:**
#    * **Name:** `nights_category`
#    * **Formula:**
#    ```sql
#    CASE
#      WHEN nights <= 2 THEN 'Weekend'
#      WHEN nights <= 7 THEN 'Week'
#      WHEN nights > 7 THEN 'Extended'
#    END
#    ```
#
# 7. Click **"Save"**
#
# ✅ **Checkpoint:** Two CASE statement calculations created
#
# ---
#
# **💡 Tip:** CASE statements are perfect for categorizing continuous values

# %% [markdown]
# ### 📊 Step 18: Create Funnel Chart with Calculated Field
#
# **Follow these steps:**
#
# 1. Click **"+ Add"** → **"Visualization"**
#
# 2. **Configure funnel chart:**
#    * **Dataset:** "bookings"
#    * **Type:** **Funnel** (or Horizontal bar if funnel not available)
#    * **Category:** `booking_tier` (your calculated field)
#    * **Value:** COUNT of `booking_id`
#    * **Title:** "Bookings by Price Tier"
#
# 3. **Sort order:**
#    * Order by value (descending)
#    * Or custom order: Budget, Standard, Premium, Luxury
#
# 4. Click **"Save"**
#
# **What you'll see:**
# * Funnel showing booking distribution across tiers
# * Budget tier (largest)
# * Standard tier
# * Premium tier
# * Luxury tier (smallest)
#
# **Funnel charts show:**
# * Progressive reduction
# * Conversion rates
# * Category distribution
# * Hierarchical data
#
# ✅ **Checkpoint:** Funnel chart using calculated booking_tier field
#
# ---
#
# **💡 Tip:** Calculated fields can be used in any visualization just like regular columns

# %% [markdown]
# ### 🎯 **Challenge 5: Advanced Calculated Fields**
#
# **Your task:**
#
# Create multiple calculated fields and use them in visualizations.
#
# **Part A: Create calculations**
#
# 1. **Calculation 1:** `revenue_per_guest`
#    ```sql
#    total_amount / guests_count
#    ```
#
# 2. **Calculation 2:** `booking_lead_time`
#    ```sql
#    DATEDIFF(check_in, created_at)
#    ```
#
# 3. **Calculation 3:** `lead_time_category`
#    ```sql
#    CASE
#      WHEN DATEDIFF(check_in, created_at) <= 7 THEN 'Last Minute'
#      WHEN DATEDIFF(check_in, created_at) <= 30 THEN 'Short Notice'
#      WHEN DATEDIFF(check_in, created_at) <= 90 THEN 'Advance'
#      ELSE 'Early Bird'
#    END
#    ```
#
# **Part B: Create visualizations**
#
# 1. **Visualization 1:** Bar chart
#    * X-axis: lead_time_category
#    * Y-axis: COUNT of bookings
#    * Title: "Bookings by Lead Time"
#
# 2. **Visualization 2:** Scatter plot
#    * X-axis: booking_lead_time
#    * Y-axis: total_amount
#    * Title: "Booking Value vs Lead Time"
#
# **Expected result:**
# * Three new calculated fields
# * Two visualizations using them
# * Insights into booking patterns
#
# ✅ **Success criteria:** Calculated fields working in visualizations
#
# ---

# %% [markdown]
# ### ✅ Custom Calculations - Key Points
#
# **Creating calculations:**
# * 👉 Go to Data tab
# * 👉 Select dataset
# * 👉 Click "+ Add calculation"
# * 👉 Enter name and formula
# * 👉 Save
#
# **Formula types:**
# * 📊 **Arithmetic:** `amount * quantity`, `price / units`
# * 📅 **Date functions:** `DATEDIFF()`, `DATE_TRUNC()`
# * 📝 **String functions:** `CONCAT()`, `UPPER()`, `SUBSTRING()`
# * 🔢 **Conditional:** `CASE WHEN ... THEN ... END`
# * 📊 **Aggregations:** Used in visualization, not calculation
#
# **Common patterns:**
# ```sql
# -- Simple math
# total_amount / nights
#
# -- Categorization
# CASE
#   WHEN value < 100 THEN 'Low'
#   WHEN value < 500 THEN 'Medium'
#   ELSE 'High'
# END
#
# -- Date calculations
# DATEDIFF(end_date, start_date)
#
# -- String manipulation
# CONCAT(first_name, ' ', last_name)
# ```
#
# **Best practices:**
# * ✅ Use descriptive names
# * ✅ Add descriptions
# * ✅ Test calculations before using
# * ✅ Keep formulas simple
# * ✅ Document business logic
#
# **Benefits:**
# * ✅ No need to modify dataset query
# * ✅ Reusable across visualizations
# * ✅ Easy to update
# * ✅ Self-documenting
#
# ---

# %% [markdown]
# ## Part 7: Publishing & Scheduling 🚀
#
# Make your dashboard available to others and keep it automatically updated.
#
# ---

# %% [markdown]
# ### 🚀 Step 19: Publish Your Dashboard
#
# **Follow these steps:**
#
# **What is publishing?**
# * Makes dashboard available to viewers
# * Switches from edit mode to view mode
# * Creates a shareable link
# * Viewers see the published version
#
# **To publish:**
#
# 1. Click the **"Publish"** button (top-right)
# 2. A confirmation dialog may appear
# 3. Review your dashboard
# 4. Click **"Publish"** to confirm
#
# **What happens:**
# * Dashboard switches to view mode
# * URL changes to published version
# * Viewers can now access it
# * Edit button available to return to edit mode
#
# **Published vs Draft:**
#
# | Mode | Purpose | Who Sees It | Can Edit |
# |------|---------|-------------|----------|
# | **Draft** | Building | Only you | Yes |
# | **Published** | Viewing | Everyone with access | No (must enter edit mode) |
#
# **After publishing:**
# * Click **"Edit"** to make changes
# * Changes are saved as draft
# * Click **"Publish"** again to update published version
#
# ✅ **Checkpoint:** Dashboard is published and viewable
#
# ---
#
# **💡 Tip:** Publish frequently to share progress with stakeholders

# %% [markdown]
# ### 🔄 Step 20: Schedule Automatic Refresh
#
# **Follow these steps:**
#
# **What is dashboard refresh?**
# * Automatically reruns all dataset queries
# * Updates all visualizations
# * Keeps dashboard current
# * Runs on a schedule
#
# **To set up refresh:**
#
# 1. Click the **three dots menu** (⋮) on the dashboard (top-right)
# 2. Select **"Schedule"** or **"Refresh schedule"**
# 3. A schedule configuration dialog opens
#
# **Configure refresh schedule:**
#
# 4. **Schedule settings:**
#    * **Enabled:** Toggle ON
#    * **Frequency:** Daily
#    * **Time:** 6:00 AM
#    * **Timezone:** Your timezone
#    * **SQL Warehouse:** Select a warehouse
#
# 5. Click **"Save"**
#
# **What happens:**
# * Dashboard queries run automatically at 6 AM daily
# * All datasets refresh
# * All visualizations update
# * Viewers see fresh data
#
# **Refresh frequency options:**
# * Every N minutes (5, 15, 30)
# * Hourly
# * Daily (specific time)
# * Weekly (specific day and time)
# * Custom cron expression
#
# **Best practices:**
# * Match refresh frequency to data update frequency
# * Schedule during off-peak hours
# * Consider warehouse costs
# * Monitor refresh history
#
# ✅ **Checkpoint:** Dashboard scheduled to refresh daily at 6 AM
#
# ---
#
# **💡 Tip:** Refresh schedules keep dashboards current without manual work

# %% [markdown]
# ### 📜 Step 21: Monitor Refresh History
#
# **Follow these steps:**
#
# 1. Click the **three dots menu** (⋮) on the dashboard
# 2. Select **"Refresh history"** or **"Schedule history"**
# 3. A panel opens showing:
#    * **Past refreshes** - Timestamps
#    * **Status** - Success or failure
#    * **Duration** - How long it took
#    * **Next refresh** - When it will run next
#
# **What to check:**
# * ✅ All refreshes succeeded
# * ✅ Execution times are reasonable
# * ✅ No errors or failures
# * ✅ Next refresh is scheduled correctly
#
# **If refresh fails:**
# * Check error message
# * Verify warehouse is available
# * Check dataset queries for errors
# * Verify permissions on tables
# * Review SQL warehouse logs
#
# **Manual refresh:**
# * Click **"Refresh"** button to run immediately
# * Useful for testing
# * Doesn't affect schedule
#
# ✅ **Checkpoint:** Can view refresh history and status
#
# ---
#
# **💡 Tip:** Monitor refresh history to ensure dashboards stay current

# %% [markdown]
# ## Part 8: Dashboard Settings & Configuration ⚙️
#
# Explore dashboard settings and learn about advanced features.
#
# ---

# %% [markdown]
# ### ⚙️ Step 22: Explore Dashboard Settings
#
# **Follow these steps:**
#
# 1. Click the **three dots menu** (⋮) on the dashboard (top-right)
# 2. Select **"Settings"** or **"Dashboard settings"**
# 3. A settings panel opens
#
# **Available settings:**
#
# **General settings:**
# * **Dashboard name** - Change title
# * **Description** - Add dashboard description
# * **Tags** - Add tags for organization
# * **Folder** - Move to different folder
#
# **Display settings:**
# * **Theme** - Light or dark mode
# * **Layout** - Grid settings
# * **Default filters** - Set default filter values
# * **Auto-refresh** - Refresh when viewing (separate from schedule)
#
# **Access settings:**
# * **Permissions** - Who can view/edit
# * **Sharing** - Generate shareable links
# * **Embedding** - Embed in external apps
#
# **Data settings:**
# * **SQL Warehouse** - Default warehouse for queries
# * **Cache settings** - Result caching duration
# * **Query timeout** - Maximum execution time
#
# **Try exploring:**
# 1. Change the dashboard description
# 2. Add tags (e.g., "analytics", "bookings")
# 3. Review permission settings
# 4. Check SQL warehouse configuration
#
# ✅ **Checkpoint:** Familiar with dashboard settings
#
# ---

# %% [markdown]
# ### 👥 Step 23: Share Your Dashboard
#
# **Follow these steps:**
#
# 1. Click the **"Share"** button (top-right)
# 2. A sharing dialog opens
#
# **Sharing options:**
#
# **Option 1: Share with users/groups**
# * Enter email addresses or group names
# * Set permissions:
#   - **Can view** - Read-only access
#   - **Can run** - Can refresh data
#   - **Can edit** - Can modify dashboard
# * Click **"Add"** or **"Share"**
#
# **Option 2: Generate shareable link**
# * Click **"Get link"** or **"Copy link"**
# * Share the URL
# * Anyone with link can view (if permissions allow)
#
# **Option 3: Embed dashboard**
# * Get embed code
# * Embed in external website or app
# * Requires proper authentication
#
# **Permission levels:**
# * 👁️ **View** - See dashboard, use filters
# * ▶️ **Run** - Refresh data manually
# * ✏️ **Edit** - Modify visualizations and settings
# * 👑 **Manage** - Change permissions, delete
#
# **Try it:**
# 1. Open the share dialog
# 2. Review permission options
# 3. (Optional) Share with a colleague
#
# ✅ **Checkpoint:** Understand sharing and permissions
#
# ---
#
# **💡 Tip:** Use "Can view" for most users, "Can edit" for dashboard developers

# %% [markdown]
# ### 📂 Step 24: Organize Your Dashboards
#
# **Follow these steps:**
#
# **Using folders:**
#
# 1. Navigate to **"Dashboards"** in the sidebar
# 2. You'll see your dashboard list
# 3. Click **"Create folder"** or **"+"**
# 4. Name it (e.g., "Booking Analytics", "Executive Reports")
# 5. **Move dashboard to folder:**
#    * Click three dots on dashboard
#    * Select "Move"
#    * Choose folder
#    * Click "Move"
#
# **Using tags:**
#
# 1. Open dashboard settings
# 2. Add tags:
#    * "analytics"
#    * "bookings"
#    * "executive"
#    * "daily-refresh"
# 3. Save
#
# **Using favorites:**
#
# 1. Click the **star icon** ⭐ on the dashboard
# 2. Dashboard is added to favorites
# 3. Quick access from "Favorites" section
#
# **Organization best practices:**
# * 📂 Use folders by department or project
# * 🏷️ Use tags for categorization
# * ⭐ Star frequently used dashboards
# * 📝 Use clear, descriptive names
#
# ✅ **Checkpoint:** Dashboard is organized and easy to find
#
# ---

# %% [markdown]
# ### 🧞 Step 25: Introduction to Genie Spaces
#
# **What's next after Dashboards?**
#
# Databricks **Genie Spaces** is the next evolution of analytics:
#
# **Genie Spaces vs Dashboards:**
#
# | Feature | Dashboards (Lakeview) | Genie Spaces |
# |---------|----------------------|---------------|
# | **Creation** | Manual (drag & drop) | AI-powered |
# | **Queries** | Write SQL | Natural language |
# | **Visualizations** | Configure manually | AI-generated |
# | **Flexibility** | High control | Conversational |
# | **Best for** | Structured reports | Ad-hoc exploration |
# | **Learning curve** | Moderate | Low |
#
# **What is Genie?**
# * 🤖 AI-powered analytics assistant
# * 💬 Ask questions in natural language
# * 📊 Automatically generates visualizations
# * 💡 Suggests insights and follow-up questions
# * 🔍 Understands your data semantics
#
# **Example Genie interactions:**
# * "Show me total bookings by property type"
# * "What's the average rating for luxury properties?"
# * "Compare revenue this month vs last month"
# * "Which properties have the highest occupancy?"
#
# **When to use each:**
#
# **Use Dashboards when:**
# * ✅ Building structured reports
# * ✅ Need precise control over layout
# * ✅ Creating executive dashboards
# * ✅ Standardized metrics
# * ✅ Scheduled refreshes
#
# **Use Genie Spaces when:**
# * ✅ Ad-hoc exploration
# * ✅ Quick questions
# * ✅ Non-technical users
# * ✅ Conversational analytics
# * ✅ Rapid prototyping
#
# **Accessing Genie:**
# 1. Click **"Genie"** in the left sidebar
# 2. Create a new Genie Space
# 3. Connect to your data
# 4. Start asking questions!
#
# ---
#
# **💡 Tip:** Dashboards for structured reports, Genie for exploration

# %% [markdown]
# ### 🎯 **Challenge 6: Build a Complete Dashboard**
#
# **Your final challenge:**
#
# Build a comprehensive dashboard using ALL features you learned!
#
# **Requirements:**
#
# **1. Dashboard setup**
# * Name: "Wanderbricks Executive Dashboard"
# * 2 pages: "Revenue Overview" and "Customer Insights"
#
# **2. Data sources (3 datasets)**
# * Dataset 1: Bookings with properties (joined)
# * Dataset 2: Reviews with ratings
# * Dataset 3: Parameterized bookings (date range)
#
# **3. Visualizations (minimum 6)**
# * Text box header
# * Counter: Total revenue
# * Pie chart: Bookings by property type
# * Line chart: Daily revenue trend (with AI forecast)
# * Bar chart: Revenue by property type
# * Funnel: Bookings by tier (using calculated field)
#
# **4. Calculated fields (minimum 2)**
# * `booking_tier` (Budget/Standard/Premium/Luxury)
# * `revenue_per_night`
#
# **5. Filters**
# * Global filter: Property type
# * Page filter: Booking status
# * Cross-filtering: Enable on pie chart
#
# **6. Parameters**
# * Date range parameter on one dataset
#
# **7. Publishing**
# * Publish the dashboard
# * Schedule daily refresh at 6 AM
# * Share with "Can view" permission
#
# **Success criteria:**
# * ✅ All visualizations working
# * ✅ Filters functioning correctly
# * ✅ Parameters updating data
# * ✅ Calculated fields in use
# * ✅ AI forecast enabled
# * ✅ Dashboard published and scheduled
#
# **Time estimate:** 45-60 minutes
#
# ---
#
# **💡 This is your capstone project - use everything you learned!**

# %% [markdown]
# ## 📊 Complete Feature Summary
#
# ### **What You Built:**
#
# **Dashboard structure:**
# * 🏷️ Named dashboard and pages
# * 💾 Multiple data sources
# * 📊 6+ visualizations
# * 🎯 Interactive filters
# * 🔄 Scheduled refreshes
#
# **Visualizations created:**
# * 📝 Text boxes - Headers and descriptions
# * 🍰 Pie charts - Category distributions
# * 📊 Bar charts - Comparisons
# * 📈 Line charts - Trends over time
# * 🔢 Counters - KPI displays
# * 📊 Funnels - Progressive metrics
#
# **Interactive features:**
# * 🔗 Cross-filtering - Click to drill down
# * 🌍 Global filters - Dashboard-wide
# * 📝 Page filters - Page-specific
# * 🎯 Widget filters - Visualization-specific
# * 🎯 Parameters - Dynamic data filtering
#
# **AI capabilities:**
# * 🤖 AI-generated visualizations
# * 🔮 AI forecasting
# * 💡 Natural language prompts
#
# **Advanced features:**
# * 🧠 Custom calculations
# * 📊 CASE statements
# * 🔄 Scheduled refreshes
# * 👥 Sharing and permissions
#
# ---

# %% [markdown]
# ## ✅ Dashboard Best Practices
#
# ### **Design Principles**
#
# **Layout:**
# * ✅ Most important metrics at the top
# * ✅ Logical flow (top to bottom, left to right)
# * ✅ Group related visualizations
# * ✅ Use consistent sizing
# * ✅ Leave white space (don't overcrowd)
#
# **Visualizations:**
# * ✅ Choose appropriate chart types
# * ✅ Use clear titles and labels
# * ✅ Consistent color schemes
# * ✅ Limit to 6-8 visualizations per page
# * ✅ Add context with text boxes
#
# **Filters:**
# * ✅ Global filters for common dimensions
# * ✅ Enable cross-filtering for exploration
# * ✅ Use parameters for date ranges
# * ✅ Don't overwhelm with too many filters
#
# **Performance:**
# * ✅ Aggregate data in dataset queries
# * ✅ Use LIMIT for large datasets
# * ✅ Schedule refreshes during off-peak
# * ✅ Monitor query execution times
# * ✅ Use appropriate SQL warehouse size
#
# **Maintenance:**
# * ✅ Document dataset queries
# * ✅ Use descriptive names
# * ✅ Monitor refresh history
# * ✅ Review and update regularly
# * ✅ Test after changes
#
# ---

# %% [markdown]
# ## 📊 Common Dashboard Patterns
#
# ### **Pattern 1: Executive Dashboard**
#
# **Structure:**
# * Top: KPI counters (revenue, users, growth)
# * Middle: Trend lines (daily/weekly/monthly)
# * Bottom: Breakdowns (by category, region, product)
#
# **Features:**
# * Global date range filter
# * AI forecasting on trends
# * Minimal clutter
# * High-level metrics
#
# ---
#
# ### **Pattern 2: Operational Dashboard**
#
# **Structure:**
# * Real-time metrics
# * Status indicators
# * Alerts for issues
# * Detailed tables
#
# **Features:**
# * Frequent refresh (every 5-15 minutes)
# * Alerts for thresholds
# * Drill-down with cross-filtering
# * Multiple pages for different areas
#
# ---
#
# ### **Pattern 3: Analytical Dashboard**
#
# **Structure:**
# * Multiple pages for different analyses
# * Detailed visualizations
# * Many filters for exploration
# * Comparative views
#
# **Features:**
# * Cross-filtering enabled
# * Multiple parameters
# * Calculated fields
# * Scatter plots and correlations
#
# ---
#
# ### **Pattern 4: Self-Service Dashboard**
#
# **Structure:**
# * User-friendly filters
# * Clear instructions
# * Multiple views of same data
# * Export options
#
# **Features:**
# * Many global filters
# * Dropdown parameters
# * Clear labels and titles
# * Help text boxes
#
# ---
#
# ### **This Demo's Dashboard**
#
# **Type:** Analytical + Executive hybrid
#
# **Features used:**
# * ✅ KPI counters
# * ✅ Trend analysis with forecasting
# * ✅ Category breakdowns
# * ✅ Interactive filters
# * ✅ Parameterized queries
# * ✅ Custom calculations
# * ✅ Scheduled refreshes
#
# ---

# %% [markdown]
# ## 🔧 Troubleshooting Common Issues
#
# **Visualization not showing data:**
# * ✅ Check dataset query returns data
# * ✅ Verify column mappings are correct
# * ✅ Check filters aren't excluding all data
# * ✅ Refresh the dataset
# * ✅ Check SQL warehouse is running
#
# **Cross-filtering not working:**
# * ✅ Verify both visualizations use **same dataset**
# * ✅ Check cross-filtering is enabled
# * ✅ Ensure common column exists
# * ✅ Try clicking different parts of the chart
#
# **Parameters not updating:**
# * ✅ Check parameter syntax: `:param_name`
# * ✅ Verify parameter widget is visible
# * ✅ Check dataset query is correct
# * ✅ Try refreshing the dashboard
#
# **Calculated field errors:**
# * ✅ Check formula syntax
# * ✅ Verify column names are correct
# * ✅ Test formula in SQL query first
# * ✅ Check for NULL handling
#
# **Schedule not running:**
# * ✅ Verify schedule is enabled
# * ✅ Check SQL warehouse is available
# * ✅ Review refresh history for errors
# * ✅ Verify permissions on tables
#
# **Dashboard slow to load:**
# * ✅ Reduce number of visualizations
# * ✅ Add LIMIT to dataset queries
# * ✅ Use aggregations in queries
# * ✅ Increase SQL warehouse size
# * ✅ Check for expensive calculations
#
# **AI features not available:**
# * ✅ Check workspace has AI features enabled
# * ✅ Verify you have appropriate permissions
# * ✅ Ensure sufficient data for forecasting
#
# ---

# %% [markdown]
# ## 📊 Quick Reference Guide
#
# ### **Dashboard Creation**
# * Create: Dashboards → Create Dashboard
# * Rename: Click title to edit
# * Pages: Right-click page tab → Rename
# * Data: Data tab → + Add dataset
#
# ---
#
# ### **Visualizations**
# * Add: + Add → Visualization
# * Types: Bar, Line, Pie, Counter, Funnel, Scatter, Area, Table
# * Edit: Click visualization → Edit
# * Delete: Click → Three dots → Delete
#
# ---
#
# ### **Filters**
# * **Cross-filter:** Visualization settings → Enable interactions
# * **Global filter:** Filters panel → + Add filter
# * **Page filter:** Page settings → + Add page filter
# * **Widget filter:** Visualization settings → Filters section
#
# ---
#
# ### **Parameters**
# * **Syntax:** `:param_name`, `:date_range.start`, `:date_range.end`
# * **Create:** Add in dataset SQL query
# * **Configure:** Parameter widget appears automatically
# * **Types:** Single value, date range, numeric range
#
# ---
#
# ### **Calculated Fields**
# * **Create:** Data tab → Dataset → + Add calculation
# * **Formula:** SQL expressions using column names
# * **Use:** Available in all visualizations
#
# ---
#
# ### **AI Features**
# * **AI viz:** + Add → AI-generated visualization
# * **Forecast:** Visualization settings → Enable forecast
# * **Prompts:** Be specific about chart type and metrics
#
# ---
#
# ### **Publishing**
# * **Publish:** Publish button (top-right)
# * **Schedule:** Three dots → Schedule
# * **Share:** Share button → Add users/groups
# * **Settings:** Three dots → Settings
#
# ---

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed the Databricks Dashboards comprehensive demo!
#
# ### **What You Learned:**
#
# ✅ **Dashboard creation** - Build from scratch
# ✅ **Data sources** - Add and configure datasets
# ✅ **Visualizations** - 7+ chart types
# ✅ **AI features** - Generate visualizations and forecasts
# ✅ **Filtering** - 4 types of filters
# ✅ **Parameters** - Dynamic data filtering
# ✅ **Calculations** - Custom fields and formulas
# ✅ **Publishing** - Share with teams
# ✅ **Scheduling** - Automatic refreshes
# ✅ **Settings** - Configuration and permissions
#
# ---
#
# ### **Key Takeaways:**
#
# 1. **Dashboards visualize data** - Turn queries into insights
# 2. **Filters enable exploration** - Interactive drill-down
# 3. **Parameters improve efficiency** - Filter at query level
# 4. **AI accelerates development** - Generate visualizations quickly
# 5. **Calculations add flexibility** - Create metrics without SQL changes
# 6. **Scheduling keeps data fresh** - Automated updates
# 7. **Cross-filtering requires same dataset** - Important limitation
# 8. **Genie Spaces for exploration** - Natural language analytics
#
# ---
#
# ### **Your Dashboard Workflow:**
#
# ```
# 1. 🏗️ Create dashboard and pages
#    ↓
# 2. 💾 Add data sources (datasets)
#    ↓
# 3. 🧠 Create calculated fields
#    ↓
# 4. 📊 Add visualizations
#    ↓
# 5. 🤖 Use AI for complex visualizations
#    ↓
# 6. 🎯 Add filters and parameters
#    ↓
# 7. 🔮 Enable AI forecasting
#    ↓
# 8. 🚀 Publish dashboard
#    ↓
# 9. 🔄 Schedule refreshes
#    ↓
# 10. 👥 Share with team
# ```
#
# ---
#
# ### **Production Checklist:**
#
# ☐ All visualizations have clear titles
# ☐ Filters have sensible defaults
# ☐ Parameters are documented
# ☐ Calculated fields are tested
# ☐ Refresh schedule is appropriate
# ☐ Permissions are set correctly
# ☐ Dashboard is organized in folders
# ☐ Performance is acceptable
# ☐ Mobile view is tested (if needed)
# ☐ Documentation is complete
#
# ---
#
# ### **Next Steps:**
#
# * Build dashboards for your own data
# * Explore Genie Spaces for conversational analytics
# * Learn about dashboard embedding
# * Create dashboard templates
# * Set up monitoring dashboards
# * Integrate with alerting systems
# * Explore advanced AI features
#
# ---
#
# ### **Resources:**
#
# * [Lakeview Dashboards Documentation](https://docs.databricks.com/dashboards/index.html)
# * [Visualization Types Guide](https://docs.databricks.com/dashboards/visualizations/index.html)
# * [Dashboard Filters](https://docs.databricks.com/dashboards/filters.html)
# * [Genie Spaces](https://docs.databricks.com/genie/index.html)
# * [Best Practices](https://docs.databricks.com/dashboards/best-practices.html)
#
# ---
#
# **You're now ready to build production dashboards!** 🚀
#
# *Happy dashboard building!*
