# %% [markdown]
# # Databricks SQL Editor - Interface Guide 🖥️
#
# Welcome! This demo will guide you through the Databricks SQL Editor interface and teach you how to use its powerful features.
#
# ---
#
# ## 🎯 What You'll Learn
#
# By the end of this demo, you will know how to:
#
# 1. ✅ Navigate the SQL Editor interface
# 2. ✅ Use the Schema Browser to explore data
# 3. ✅ Write queries with autocomplete and syntax highlighting
# 4. ✅ Format and organize your SQL code
# 5. ✅ Manage multiple query tabs
# 6. ✅ Execute queries and view results
# 7. ✅ Save and organize your queries
# 8. ✅ Use keyboard shortcuts for efficiency
#
# ---
#
# ## 📍 What is Databricks SQL Editor?
#
# The **Databricks SQL Editor** is a web-based IDE for writing and executing SQL queries against your data lakehouse.
#
# **Key features:**
# * 🔍 Schema Browser - Explore tables and columns
# * ✍️ Intelligent code editor - Autocomplete, syntax highlighting
# * 📑 Tab management - Work on multiple queries
# * ⚡ Fast execution - Serverless SQL warehouses
# * 💾 Query library - Save and share queries
# * 📊 Results visualization - Tables and charts
#
# ---
#
# ## 🚀 Getting Started
#
# **To access SQL Editor:**
# 1. Click **SQL Editor** in the left sidebar
# 2. Or navigate to `/sql/editor` in your workspace
#
# **Prerequisites:**
# * Access to a Databricks workspace
# * SQL warehouse (serverless or classic)
# * Permissions to query data
#
# ---
#
# **Let's explore the interface!** 👇

# %% [markdown]
# ## 1. Schema Browser 🔍
#
# The **Schema Browser** is your data catalog - it shows all available databases, tables, and columns.
#
# **Location:** Left sidebar of SQL Editor
#
# ---
#
# ### 📍 Interface Overview
#
# The Schema Browser has a hierarchical structure:
#
# ```
# 📁 Catalog (e.g., main, samples)
#   └─ 📂 Schema/Database (e.g., default, nyctaxi)
#       └─ 📊 Table (e.g., customers, orders)
#           └─ 📝 Columns (name, type, description)
# ```
#
# **Three-level namespace:**
# * **Catalog** - Top-level container (Unity Catalog)
# * **Schema** - Database/schema within catalog
# * **Table** - Actual data table
#
# **Full table name:** `catalog.schema.table`
#
# ---

# %% [markdown]
# ### 📚 Step 1: Explore Catalogs
#
# **Try this:**
#
# 1. Look at the **Schema Browser** on the left side
# 2. You'll see a list of catalogs (e.g., `main`, `samples`)
# 3. Click the **dropdown arrow** next to a catalog name to expand it
#
# **What you'll see:**
# * 📁 **main** - Your workspace's default catalog
# * 📁 **samples** - Sample datasets provided by Databricks
# * 📁 Other catalogs - If your organization has created them
#
# **Try it now:**
# * Expand the `samples` catalog
# * You should see schemas like `nyctaxi`, `tpch`
#
# ---
#
# **💡 Tip:** Catalogs organize data by domain or team (e.g., marketing, sales, engineering)

# %% [markdown]
# ### 💾 Step 2: Explore Schemas
#
# **Try this:**
#
# 1. Expand a catalog (e.g., `samples`)
# 2. You'll see a list of schemas (databases)
# 3. Click the **dropdown arrow** next to a schema to expand it
#
# **Example: samples.nyctaxi**
# * Contains New York City taxi trip data
# * Multiple tables with different data
#
# **Try it now:**
# * Expand `samples.nyctaxi`
# * You should see tables like `trips`
#
# ---
#
# **💡 Tip:** Schemas group related tables together (e.g., all sales tables in one schema)

# %% [markdown]
# ### 📊 Step 3: Explore Tables
#
# **Try this:**
#
# 1. Expand a schema (e.g., `samples.nyctaxi`)
# 2. You'll see a list of tables
# 3. Click on a **table name** to see its details
#
# **What you'll see when you click a table:**
# * 📝 **Columns** - Column names and data types
# * 📊 **Sample data** - Preview of actual data
# * 📝 **Details** - Table properties, location, format
# * 🔗 **Lineage** - Where data comes from (if available)
#
# **Try it now:**
# * Click on `samples.nyctaxi.trips`
# * Explore the columns and sample data
#
# ---
#
# **💡 Tip:** Hover over a table name to see a quick preview tooltip

# %% [markdown]
# ### 📝 Step 4: View Column Details
#
# **Try this:**
#
# 1. Click on a table in the Schema Browser
# 2. The **Columns** tab shows all columns
# 3. Each column shows:
#    * 🏷️ **Column name**
#    * 📊 **Data type** (INT, STRING, DATE, etc.)
#    * 📝 **Description** (if available)
#    * 🔑 **Key indicator** (primary key, partition key)
#
# **Example: samples.nyctaxi.trips**
#
# You might see columns like:
# * `tpep_pickup_datetime` - TIMESTAMP
# * `trip_distance` - DOUBLE
# * `fare_amount` - DOUBLE
# * `pickup_zip` - INT
#
# **Try it now:**
# * Explore the columns in `samples.nyctaxi.trips`
# * Note the data types
#
# ---
#
# **💡 Tip:** Understanding column types helps you write correct queries

# %% [markdown]
# ### ⚡ Step 5: Quick Insert Table/Column Names
#
# **Try this:**
#
# You can quickly insert table and column names into your query:
#
# **Method 1: Click to insert**
# 1. Click on a **table name** in Schema Browser
# 2. Click the **"Insert"** button (or three dots menu)
# 3. The full table name appears in your query!
#
# **Method 2: Drag and drop**
# 1. Click and **drag** a table name from Schema Browser
# 2. **Drop** it into your query editor
# 3. The table name is inserted
#
# **Method 3: Double-click**
# 1. **Double-click** a table name
# 2. It's inserted at your cursor position
#
# **Try it now:**
# 1. Clear your query editor
# 2. Type: `SELECT * FROM `
# 3. Use Schema Browser to insert `samples.nyctaxi.trips`
# 4. Your query should be: `SELECT * FROM samples.nyctaxi.trips`
#
# ---
#
# **💡 Tip:** This prevents typos in table names!

# %% [markdown]
# ### 🔎 Step 6: Search for Tables
#
# **Try this:**
#
# The Schema Browser has a **search box** at the top:
#
# 1. Look for the **search icon** 🔍 at the top of Schema Browser
# 2. Click it to open the search box
# 3. Type a table name (e.g., "trips")
# 4. Results show matching tables across all catalogs
#
# **Search features:**
# * Searches across all catalogs and schemas
# * Matches table names and descriptions
# * Shows full path (catalog.schema.table)
# * Click result to navigate to that table
#
# **Try it now:**
# 1. Click the search icon in Schema Browser
# 2. Search for "trips"
# 3. Click on a result to see that table
#
# ---
#
# **💡 Tip:** Use search when you know the table name but not its location

# %% [markdown]
# ### ✅ Schema Browser - Key Actions
#
# **Navigation:**
# * 👉 Click dropdown arrows to expand/collapse
# * 👉 Click table names to view details
# * 👉 Use search to find tables quickly
#
# **Viewing information:**
# * 👉 Columns tab - See all columns and types
# * 👉 Sample data tab - Preview actual data
# * 👉 Details tab - Table metadata
# * 👉 Hover tooltips - Quick information
#
# **Inserting into queries:**
# * 👉 Click "Insert" button
# * 👉 Drag and drop
# * 👉 Double-click table name
#
# **Benefits:**
# * ✅ Discover available data
# * ✅ Understand table structure
# * ✅ Avoid typos in table names
# * ✅ Learn column data types
# * ✅ See sample data before querying
#
# ---

# %% [markdown]
# ## 2. Query Editor Features ✍️
#
# The **Query Editor** is where you write your SQL code. It has intelligent features to help you write queries faster and with fewer errors.
#
# **Location:** Center panel of SQL Editor
#
# ---

# %% [markdown]
# ### ✨ Step 7: Autocomplete (IntelliSense)
#
# The editor provides **intelligent autocomplete** as you type.
#
# **Try this:**
#
# 1. Start typing in the query editor: `SELECT * FROM sam`
# 2. A dropdown menu appears with suggestions
# 3. You'll see:
#    * 📁 Matching catalogs (samples)
#    * 📊 Matching tables
#    * 📝 SQL keywords
# 4. Use **arrow keys** to navigate suggestions
# 5. Press **Tab** or **Enter** to accept
#
# **Autocomplete triggers:**
# * After typing a few characters
# * After typing `.` (dot) for catalog.schema.table
# * After `FROM`, `JOIN`, `WHERE` keywords
# * When typing column names
#
# **Try it now:**
# ```sql
# SELECT * FROM samples.nyc
# ```
# * Type this and watch autocomplete suggest `nyctaxi`
# * Press Tab to complete
#
# ---
#
# **💡 Tip:** Press `Ctrl+Space` (Windows/Linux) or `Cmd+Space` (Mac) to manually trigger autocomplete

# %% [markdown]
# ### 📝 Step 8: Column Name Autocomplete
#
# Autocomplete also works for **column names**!
#
# **Try this:**
#
# 1. Type a query with a table:
# ```sql
# SELECT
#
# FROM samples.nyctaxi.trips
# ```
# 2. Put your cursor after `SELECT`
# 3. Start typing a column name (e.g., `fare`)
# 4. Autocomplete suggests matching columns: `fare_amount`
# 5. Press Tab to insert
#
# **Column autocomplete features:**
# * Shows columns from tables in your query
# * Shows data types next to column names
# * Filters as you type
# * Prevents typos
#
# **Try it now:**
# 1. Write: `SELECT fare FROM samples.nyctaxi.trips`
# 2. Watch autocomplete suggest `fare_amount`
# 3. Complete the query and add `LIMIT 10`
#
# ---
#
# **💡 Tip:** Autocomplete knows which columns belong to which table in multi-table queries

# %% [markdown]
# ### 🎨 Step 9: Syntax Highlighting
#
# The editor uses **color coding** to make SQL easier to read.
#
# **Color scheme:**
# * 🔵 **Blue** - SQL keywords (SELECT, FROM, WHERE, JOIN)
# * 🟢 **Green** - Strings ('text values')
# * 🟪 **Purple** - Numbers (123, 45.67)
# * ⚫ **Black/White** - Table and column names
# * 🟠 **Orange** - Functions (COUNT, SUM, AVG)
# * 🟢 **Gray** - Comments (-- comment)
#
# **Try this:**
#
# Type this query and observe the colors:
# ```sql
# SELECT
#   pickup_zip,
#   COUNT(*) AS trip_count,
#   AVG(fare_amount) AS avg_fare
# FROM samples.nyctaxi.trips
# WHERE fare_amount > 10
# GROUP BY pickup_zip
# LIMIT 10
# ```
#
# **Benefits:**
# * ✅ Easier to read
# * ✅ Spot errors quickly
# * ✅ Understand query structure
# * ✅ Identify keywords vs identifiers
#
# ---

# %% [markdown]
# ### 📝 Step 10: Format Your SQL Code
#
# The editor can **automatically format** your SQL for better readability.
#
# **Try this:**
#
# 1. Write a messy query (all on one line):
# ```sql
# SELECT pickup_zip,COUNT(*) AS trip_count,AVG(fare_amount) AS avg_fare FROM samples.nyctaxi.trips WHERE fare_amount>10 GROUP BY pickup_zip LIMIT 10
# ```
#
# 2. Right-click in the editor
# 3. Select **"Format SQL"** from the context menu
# 4. Or use keyboard shortcut:
#    * **Windows/Linux:** `Shift+Alt+F`
#    * **Mac:** `Shift+Option+F`
#
# **Result:**
# ```sql
# SELECT
#   pickup_zip,
#   COUNT(*) AS trip_count,
#   AVG(fare_amount) AS avg_fare
# FROM samples.nyctaxi.trips
# WHERE fare_amount > 10
# GROUP BY pickup_zip
# LIMIT 10
# ```
#
# **Try it now:**
# 1. Write a messy query
# 2. Format it using the keyboard shortcut
# 3. See how much more readable it becomes!
#
# ---
#
# **💡 Tip:** Format your queries regularly for better readability and collaboration

# %% [markdown]
# ### ⚠️ Step 11: Error Detection and Warnings
#
# The editor highlights **syntax errors** as you type.
#
# **Try this:**
#
# 1. Type an invalid query:
# ```sql
# SELECT * FORM samples.nyctaxi.trips
# ```
# (Notice: "FORM" instead of "FROM")
#
# 2. You'll see:
#    * 🔴 **Red squiggly underline** under the error
#    * **Hover** over it to see the error message
#    * Error message explains what's wrong
#
# **Common errors detected:**
# * Misspelled keywords (FORM instead of FROM)
# * Missing commas
# * Unclosed quotes
# * Invalid syntax
# * Unknown table names (sometimes)
#
# **Try it now:**
# 1. Type: `SELCT * FROM samples.nyctaxi.trips`
# 2. Hover over the red underline
# 3. Fix the error to `SELECT`
#
# ---
#
# **💡 Tip:** Fix errors before running - saves time and compute resources!

# %% [markdown]
# ### 💬 Step 12: Adding Comments
#
# Comments help document your queries.
#
# **Single-line comments:**
# ```sql
# -- This is a single-line comment
# SELECT * FROM samples.nyctaxi.trips
# ```
#
# **Multi-line comments:**
# ```sql
# /*
#   This is a multi-line comment
#   You can write multiple lines
#   Useful for longer explanations
# */
# SELECT * FROM samples.nyctaxi.trips
# ```
#
# **Try this:**
#
# 1. Add comments to your query:
# ```sql
# -- Query: Analyze taxi trips by pickup location
# -- Author: Your Name
# -- Date: 2026-01-20
#
# SELECT
#   pickup_zip,
#   COUNT(*) AS trip_count  -- Count trips per location
# FROM samples.nyctaxi.trips
# WHERE fare_amount > 10  -- Filter expensive trips
# GROUP BY pickup_zip
# LIMIT 10
# ```
#
# **Best practices:**
# * ✅ Explain complex logic
# * ✅ Document assumptions
# * ✅ Add query metadata (author, date, purpose)
# * ✅ Comment out code for testing
#
# ---
#
# **💡 Tip:** Use `Ctrl+/` (Windows/Linux) or `Cmd+/` (Mac) to quickly comment/uncomment lines

# %% [markdown]
# ### ✅ Query Editor - Key Features
#
# **Intelligent editing:**
# * ✨ Autocomplete - Table and column suggestions
# * 🎨 Syntax highlighting - Color-coded SQL
# * ⚠️ Error detection - Red underlines for errors
# * 📝 Auto-formatting - Clean, readable code
#
# **Productivity shortcuts:**
# * `Ctrl+Space` / `Cmd+Space` - Trigger autocomplete
# * `Shift+Alt+F` / `Shift+Option+F` - Format SQL
# * `Ctrl+/` / `Cmd+/` - Toggle comment
# * `Ctrl+Enter` / `Cmd+Enter` - Run query
#
# **Code organization:**
# * `--` Single-line comments
# * `/* */` Multi-line comments
# * Indentation for readability
# * Consistent formatting
#
# **Benefits:**
# * ✅ Write queries faster
# * ✅ Fewer typos and errors
# * ✅ More readable code
# * ✅ Better collaboration
#
# ---

# %% [markdown]
# ## 3. Tab Management 📑
#
# Work on **multiple queries simultaneously** using tabs - just like a web browser!
#
# **Location:** Top of the query editor area
#
# ---

# %% [markdown]
# ### ➕ Step 13: Create New Query Tabs
#
# **Try this:**
#
# You can create new tabs in several ways:
#
# **Method 1: Plus button**
# 1. Look at the top of the query editor
# 2. Find the **"+"** button next to existing tabs
# 3. Click it to create a new tab
#
# **Method 2: Keyboard shortcut**
# * **Windows/Linux:** `Ctrl+Alt+N`
# * **Mac:** `Cmd+Option+N`
#
# **Method 3: From menu**
# 1. Click the **"Create"** button (top right)
# 2. Select **"Query"**
#
# **What happens:**
# * A new untitled tab opens
# * Empty query editor ready for your SQL
# * Independent from other tabs
#
# **Try it now:**
# 1. Create a new tab using the + button
# 2. You should now have 2 tabs open
#
# ---
#
# **💡 Tip:** Use separate tabs for different analyses or queries you're working on

# %% [markdown]
# ### 🔄 Step 14: Switch Between Tabs
#
# **Try this:**
#
# Navigate between your open tabs:
#
# **Method 1: Click tabs**
# 1. Click on any tab name at the top
# 2. That tab becomes active
#
# **Method 2: Keyboard shortcuts**
# * **Next tab:** `Ctrl+Tab` (Windows/Linux) or `Cmd+Tab` (Mac)
# * **Previous tab:** `Ctrl+Shift+Tab` or `Cmd+Shift+Tab`
# * **Specific tab:** `Ctrl+1`, `Ctrl+2`, etc. (first 9 tabs)
#
# **Tab indicators:**
# * ⚪ **White dot** - Unsaved changes
# * 🟢 **No dot** - All changes saved
# * **Bold text** - Currently active tab
#
# **Try it now:**
# 1. Open 2-3 tabs
# 2. Write different queries in each
# 3. Practice switching between them with keyboard shortcuts
#
# ---
#
# **💡 Tip:** Keep related queries in separate tabs for easy comparison

# %% [markdown]
# ### ❌ Step 15: Close Tabs
#
# **Try this:**
#
# Close tabs you no longer need:
#
# **Method 1: X button**
# 1. Hover over a tab
# 2. Click the **"X"** that appears
# 3. Tab closes
#
# **Method 2: Middle-click**
# 1. Middle-click (scroll wheel click) on a tab
# 2. Tab closes immediately
#
# **Method 3: Keyboard shortcut**
# * **Windows/Linux:** `Ctrl+W`
# * **Mac:** `Cmd+W`
#
# **Unsaved changes warning:**
# * If tab has unsaved changes (white dot)
# * You'll get a confirmation dialog
# * Choose: Save, Don't Save, or Cancel
#
# **Try it now:**
# 1. Create a new tab
# 2. Type some SQL
# 3. Try to close it - you'll see the warning
# 4. Choose "Don't Save" (it's just a test)
#
# ---
#
# **💡 Tip:** Close unused tabs to keep your workspace organized

# %% [markdown]
# ### ✏️ Step 16: Rename Query Tabs
#
# **Try this:**
#
# Give your queries descriptive names:
#
# **Method 1: Click to rename**
# 1. Click on the **tab name** (e.g., "Untitled Query")
# 2. The name becomes editable
# 3. Type a new name (e.g., "Daily Sales Analysis")
# 4. Press **Enter** to save
#
# **Method 2: From query header**
# 1. Look at the top of the query editor
# 2. Click the **query title** (large text)
# 3. Edit the name
# 4. Press Enter
#
# **Naming best practices:**
# * ✅ Use descriptive names ("Customer Revenue Report")
# * ✅ Include purpose ("Debug - Order Duplicates")
# * ✅ Add date if relevant ("Q4 2024 Sales")
# * ❌ Avoid generic names ("Query 1", "Test")
#
# **Try it now:**
# 1. Rename your current tab to "Taxi Trip Analysis"
# 2. The tab name updates immediately
#
# ---
#
# **💡 Tip:** Good names help you find queries later in your query history

# %% [markdown]
# ### ✅ Tab Management - Key Actions
#
# **Creating tabs:**
# * 👉 Click **+** button
# * 👉 `Ctrl+Alt+N` / `Cmd+Option+N`
# * 👉 Create button → Query
#
# **Switching tabs:**
# * 👉 Click tab name
# * 👉 `Ctrl+Tab` / `Cmd+Tab` (next)
# * 👉 `Ctrl+Shift+Tab` / `Cmd+Shift+Tab` (previous)
# * 👉 `Ctrl+1`, `Ctrl+2`, etc. (specific tab)
#
# **Closing tabs:**
# * 👉 Click **X** on tab
# * 👉 Middle-click tab
# * 👉 `Ctrl+W` / `Cmd+W`
#
# **Renaming tabs:**
# * 👉 Click tab name to edit
# * 👉 Click query title in editor
#
# **Benefits:**
# * ✅ Work on multiple queries at once
# * ✅ Compare different approaches
# * ✅ Organize your work
# * ✅ Quick context switching
#
# ---

# %% [markdown]
# ## 4. Running Queries & Viewing Results ⚡
#
# Learn how to execute your queries and work with results.
#
# ---

# %% [markdown]
# ### 💾 Step 17: Select a SQL Warehouse
#
# Before running queries, you need to select a **SQL warehouse** (compute resource).
#
# **Try this:**
#
# 1. Look at the **top-right** of the SQL Editor
# 2. Find the **warehouse dropdown** (shows current warehouse or "Select warehouse")
# 3. Click the dropdown
# 4. You'll see available warehouses:
#    * **Serverless** - Fast, auto-scaling (recommended)
#    * **Classic** - Traditional SQL warehouses
# 5. Select a warehouse
#
# **Warehouse states:**
# * 🟢 **Running** - Ready to execute queries
# * 🟡 **Starting** - Warming up (wait a moment)
# * ⚫ **Stopped** - Click to start
#
# **Try it now:**
# 1. Select a serverless warehouse (if available)
# 2. Wait for it to show "Running" status
# 3. You're ready to execute queries!
#
# ---
#
# **💡 Tip:** Serverless warehouses start instantly and scale automatically

# %% [markdown]
# ### ▶️ Step 18: Execute Your Query
#
# **Try this:**
#
# Write and run a simple query:
#
# 1. Type this query:
# ```sql
# SELECT
#   pickup_zip,
#   COUNT(*) AS trip_count
# FROM samples.nyctaxi.trips
# GROUP BY pickup_zip
# ORDER BY trip_count DESC
# LIMIT 10
# ```
#
# 2. Click the **"Run"** button (blue button, top-right of editor)
# 3. Or use keyboard shortcut:
#    * **Windows/Linux:** `Ctrl+Enter`
#    * **Mac:** `Cmd+Enter`
#
# **What happens:**
# * Query is sent to the SQL warehouse
# * Execution starts immediately
# * Progress indicator shows status
# * Results appear below the editor
#
# **Try it now:**
# 1. Write the query above
# 2. Press `Ctrl+Enter` / `Cmd+Enter` to run
# 3. Wait for results to appear
#
# ---
#
# **💡 Tip:** `Ctrl+Enter` / `Cmd+Enter` is the fastest way to run queries!

# %% [markdown]
# ### 🎯 Step 19: Run Selected SQL Only
#
# You can run **part of your query** without running everything.
#
# **Try this:**
#
# 1. Write multiple queries in one tab:
# ```sql
# -- Query 1
# SELECT COUNT(*) FROM samples.nyctaxi.trips;
#
# -- Query 2
# SELECT * FROM samples.nyctaxi.trips LIMIT 5;
#
# -- Query 3
# SELECT AVG(fare_amount) FROM samples.nyctaxi.trips;
# ```
#
# 2. **Highlight** Query 2 with your mouse
# 3. Click **"Run"** or press `Ctrl+Enter` / `Cmd+Enter`
# 4. Only the selected query runs!
#
# **Use cases:**
# * Test individual queries in a multi-query file
# * Debug specific parts
# * Run queries in different order
# * Skip expensive queries
#
# **Try it now:**
# 1. Write the 3 queries above
# 2. Highlight just the second query
# 3. Run only that query
#
# ---
#
# **💡 Tip:** This is great for testing and debugging complex query files

# %% [markdown]
# ### 📊 Step 20: View Query Results
#
# After running a query, results appear in the **Results panel** below the editor.
#
# **Try this:**
#
# 1. Run a query (any query)
# 2. Look at the **Results panel** below
# 3. You'll see:
#    * 📊 **Table view** - Data in rows and columns
#    * 🔢 **Row count** - Number of rows returned
#    * ⏱️ **Execution time** - How long it took
#    * 💾 **Download button** - Export results
#
# **Result panel features:**
# * **Scrollable** - Scroll horizontally and vertically
# * **Sortable** - Click column headers to sort
# * **Resizable** - Drag the divider to resize
# * **Collapsible** - Minimize to see more of your query
#
# **Try it now:**
# 1. Run: `SELECT * FROM samples.nyctaxi.trips LIMIT 100`
# 2. Explore the results:
#    * Scroll through rows
#    * Click column headers to sort
#    * Resize the results panel
#
# ---
#
# **💡 Tip:** Results are limited to 1000 rows by default in the preview

# %% [markdown]
# ### ⏱️ Step 21: Monitor Query Execution
#
# Watch your query's progress in real-time.
#
# **Try this:**
#
# 1. Run a longer query:
# ```sql
# SELECT
#   pickup_zip,
#   DATE(tpep_pickup_datetime) AS trip_date,
#   COUNT(*) AS trip_count,
#   AVG(fare_amount) AS avg_fare,
#   SUM(trip_distance) AS total_distance
# FROM samples.nyctaxi.trips
# GROUP BY pickup_zip, DATE(tpep_pickup_datetime)
# ORDER BY trip_count DESC
# ```
#
# 2. Watch the **status indicators**:
#    * 🔵 **"Running..."** - Query is executing
#    * ⏱️ **Timer** - Shows elapsed time
#    * 📄 **Progress bar** - Shows completion (if available)
#    * ❌ **Cancel button** - Stop the query if needed
#
# **Query states:**
# * 🔵 **Running** - Currently executing
# * 🟢 **Succeeded** - Completed successfully
# * 🔴 **Failed** - Error occurred
# * ⚫ **Cancelled** - You stopped it
#
# **Try it now:**
# 1. Run the query above
# 2. Watch the status change from "Running" to "Succeeded"
# 3. Note the execution time
#
# ---
#
# **💡 Tip:** Click the cancel button (X) if a query is taking too long

# %% [markdown]
# ### 💾 Step 22: Download Query Results
#
# Export your results for use in other tools.
#
# **Try this:**
#
# 1. Run a query with results
# 2. Look at the **Results panel**
# 3. Find the **download button** (usually top-right of results)
# 4. Click it to see download options:
#    * **CSV** - Comma-separated values
#    * **TSV** - Tab-separated values
#    * **Excel** - .xlsx format (if available)
#    * **JSON** - JSON format
#
# **Download options:**
# * **Current page** - Only visible rows
# * **All results** - Complete result set (up to limit)
#
# **Try it now:**
# 1. Run: `SELECT * FROM samples.nyctaxi.trips LIMIT 50`
# 2. Click the download button
# 3. Choose CSV format
# 4. File downloads to your computer
#
# ---
#
# **💡 Tip:** Use CSV for Excel, TSV for data analysis tools, JSON for APIs

# %% [markdown]
# ### ✅ Execution Features - Key Actions
#
# **Before running:**
# * 👉 Select SQL warehouse (top-right dropdown)
# * 👉 Ensure warehouse is running
# * 👉 Check query for errors
#
# **Running queries:**
# * 👉 Click **Run** button
# * 👉 `Ctrl+Enter` / `Cmd+Enter` (run all)
# * 👉 Highlight + `Ctrl+Enter` (run selection)
# * 👉 Click **Cancel** to stop
#
# **Viewing results:**
# * 👉 Results panel below editor
# * 👉 Click column headers to sort
# * 👉 Scroll to see more data
# * 👉 Resize panel with divider
#
# **Exporting results:**
# * 👉 Download button in results panel
# * 👉 Choose format (CSV, TSV, JSON)
# * 👉 Select current page or all results
#
# **Monitoring:**
# * 👉 Watch execution status
# * 👉 Check execution time
# * 👉 View row count
#
# **Benefits:**
# * ✅ Fast query execution
# * ✅ Real-time progress monitoring
# * ✅ Easy result exploration
# * ✅ Export for external use
#
# ---

# %% [markdown]
# ## 5. Saving & Organizing Queries 💾
#
# Learn how to save your work and keep your queries organized.
#
# ---

# %% [markdown]
# ### 💾 Step 23: Save Your Query
#
# Save your query to access it later.
#
# **Try this:**
#
# 1. Write a query in the editor
# 2. Click the **"Save"** button (top-right, next to Run)
# 3. Or use keyboard shortcut:
#    * **Windows/Linux:** `Ctrl+S`
#    * **Mac:** `Cmd+S`
#
# **First time saving:**
# * A dialog appears asking for a name
# * Enter a descriptive name (e.g., "Top Pickup Locations")
# * Choose a folder (optional)
# * Click "Save"
#
# **After first save:**
# * `Ctrl+S` / `Cmd+S` saves immediately
# * No dialog appears
# * Tab name updates (no white dot)
#
# **Auto-save:**
# * Queries auto-save as drafts
# * But explicit saving is recommended
# * Saved queries appear in your query list
#
# **Try it now:**
# 1. Write a simple query
# 2. Press `Ctrl+S` / `Cmd+S`
# 3. Name it "My First Query"
# 4. Click Save
#
# ---
#
# **💡 Tip:** Save frequently to avoid losing work!

# %% [markdown]
# ### 📝 Step 24: Save As (Duplicate Query)
#
# Create a copy of an existing query.
#
# **Try this:**
#
# 1. Open a saved query
# 2. Click the **three dots menu** (⋮) next to the Save button
# 3. Select **"Save as"**
# 4. Enter a new name
# 5. Choose a folder
# 6. Click "Save"
#
# **Use cases:**
# * Create variations of a query
# * Make a backup before major changes
# * Share a template with your team
# * Create monthly/weekly versions
#
# **Example:**
# * Original: "Sales Report - January"
# * Save as: "Sales Report - February"
# * Modify dates in the new copy
#
# **Try it now:**
# 1. Open your saved query
# 2. Use "Save as" to create "My First Query - Copy"
# 3. You now have two separate queries
#
# ---
#
# **💡 Tip:** Use "Save as" to create query templates for recurring analyses

# %% [markdown]
# ### 📜 Step 25: Access Your Query History
#
# View all your previously executed queries.
#
# **Try this:**
#
# 1. Look at the **left sidebar**
# 2. Click **"Queries"** (or navigate to SQL Editor home)
# 3. You'll see tabs:
#    * **"My queries"** - Queries you created
#    * **"Recent"** - Recently run queries
#    * **"Favorites"** - Queries you starred
#    * **"Shared with me"** - Queries others shared
#
# **Query list shows:**
# * 📝 Query name
# * 👤 Owner
# * 📅 Last modified date
# * ⭐ Favorite star (click to favorite)
#
# **Try it now:**
# 1. Navigate to "Queries" in the sidebar
# 2. Click "My queries" tab
# 3. Find your saved query
# 4. Click it to open
#
# ---
#
# **💡 Tip:** Use favorites (⭐) to quickly access your most-used queries

# %% [markdown]
# ### 📂 Step 26: Organize Queries with Folders
#
# Keep your queries organized using folders.
#
# **Try this:**
#
# **Create a folder:**
# 1. Go to **"Queries"** in the sidebar
# 2. Click **"Create"** button
# 3. Select **"Folder"**
# 4. Name it (e.g., "Sales Analysis", "Data Quality Checks")
# 5. Click "Create"
#
# **Move query to folder:**
# 1. Find a query in your list
# 2. Click the **three dots menu** (⋮) on the query
# 3. Select **"Move"**
# 4. Choose the destination folder
# 5. Click "Move"
#
# **Folder structure example:**
# ```
# 📂 Sales Analysis
#   └─ Daily Sales Report
#   └─ Monthly Revenue
#   └─ Customer Segments
# 📂 Data Quality
#   └─ Check Duplicates
#   └─ Validate Nulls
# 📂 Ad-Hoc Analysis
#   └─ Exploration queries
# ```
#
# **Try it now:**
# 1. Create a folder called "Practice Queries"
# 2. Move your saved query into it
# 3. Navigate to the folder to see your query
#
# ---
#
# **💡 Tip:** Use folders to organize by project, team, or purpose

# %% [markdown]
# ### 🏷️ Step 27: Query Naming Best Practices
#
# Good names make queries easy to find and understand.
#
# **Naming conventions:**
#
# **✅ Good names:**
# * "Daily Sales by Region - 2024"
# * "Customer Churn Analysis"
# * "Top 10 Products by Revenue"
# * "Data Quality - Check Nulls in Orders"
# * "Weekly Active Users (WAU)"
#
# **❌ Bad names:**
# * "Query 1"
# * "Test"
# * "Untitled"
# * "asdf"
# * "New Query"
#
# **Naming patterns:**
#
# **Pattern 1: Purpose-based**
# * Format: `[Purpose] - [Details]`
# * Example: "Revenue Report - Q4 2024"
#
# **Pattern 2: Metric-based**
# * Format: `[Metric] by [Dimension]`
# * Example: "Sales by Region and Product"
#
# **Pattern 3: Action-based**
# * Format: `[Action] [Object]`
# * Example: "Calculate Customer Lifetime Value"
#
# **Include in name:**
# * ✅ What the query does
# * ✅ Time period (if relevant)
# * ✅ Key dimensions
# * ✅ Status (Draft, Final, Archive)
#
# ---
#
# **💡 Tip:** Consistent naming helps your team find and understand queries

# %% [markdown]
# ### ✅ Saving & Organizing - Key Actions
#
# **Saving:**
# * 👉 `Ctrl+S` / `Cmd+S` - Save query
# * 👉 "Save as" - Create copy
# * 👉 Auto-save - Drafts saved automatically
# * 👉 White dot on tab - Unsaved changes
#
# **Accessing queries:**
# * 👉 "Queries" in sidebar - View all queries
# * 👉 "My queries" - Your queries
# * 👉 "Recent" - Recently run
# * 👉 "Favorites" - Starred queries
#
# **Organizing:**
# * 👉 Create folders - Group related queries
# * 👉 Move queries - Drag or use menu
# * 👉 Use descriptive names - Easy to find
# * 👉 Star favorites - Quick access
#
# **Naming conventions:**
# * 👉 Descriptive names - What it does
# * 👉 Include context - Time period, purpose
# * 👉 Consistent format - Team standard
# * 👉 Avoid generic names - "Query 1", "Test"
#
# **Benefits:**
# * ✅ Never lose your work
# * ✅ Easy to find queries later
# * ✅ Share with team members
# * ✅ Organized workspace
#
# ---

# %% [markdown]
# ## 6. SQL Editor Best Practices ✅
#
# Tips for working efficiently in the SQL Editor.
#
# ---

# %% [markdown]
# ### 🚀 Efficient Workflow Tips
#
# **1. Start with Schema Browser**
# * ✅ Explore tables before writing queries
# * ✅ Check column names and types
# * ✅ View sample data to understand structure
# * ✅ Use insert/drag to avoid typos
#
# **2. Use Autocomplete**
# * ✅ Let autocomplete suggest table names
# * ✅ Use `Ctrl+Space` / `Cmd+Space` when needed
# * ✅ Accept suggestions with Tab
# * ✅ Saves time and prevents errors
#
# **3. Format Your Code**
# * ✅ Use `Shift+Alt+F` / `Shift+Option+F` regularly
# * ✅ Consistent formatting improves readability
# * ✅ Makes debugging easier
# * ✅ Better for team collaboration
#
# **4. Add Comments**
# * ✅ Document complex logic
# * ✅ Explain business rules
# * ✅ Add query metadata (author, date, purpose)
# * ✅ Use `Ctrl+/` / `Cmd+/` for quick commenting
#
# **5. Use Multiple Tabs**
# * ✅ Separate tabs for different analyses
# * ✅ Keep reference queries open
# * ✅ Compare different approaches
# * ✅ Don't clutter one tab with everything
#
# **6. Save Frequently**
# * ✅ Use `Ctrl+S` / `Cmd+S` often
# * ✅ Give queries descriptive names
# * ✅ Organize into folders
# * ✅ Star important queries
#
# **7. Test with LIMIT**
# * ✅ Add `LIMIT 10` when testing
# * ✅ Verify logic with small results
# * ✅ Remove LIMIT for production
# * ✅ Saves time and compute
#
# **8. Use Run Selection**
# * ✅ Highlight and run specific queries
# * ✅ Test parts of complex queries
# * ✅ Debug step by step
# * ✅ Skip expensive operations
#
# ---

# %% [markdown]
# ### ⌨️ Keyboard Shortcuts Reference
#
# Master these shortcuts for maximum productivity!
#
# **Query Execution:**
# * `Ctrl+Enter` / `Cmd+Enter` - **Run query**
# * `Ctrl+Shift+Enter` / `Cmd+Shift+Enter` - Run all queries
#
# **Editing:**
# * `Ctrl+S` / `Cmd+S` - **Save query**
# * `Ctrl+Z` / `Cmd+Z` - Undo
# * `Ctrl+Y` / `Cmd+Y` - Redo
# * `Ctrl+/` / `Cmd+/` - **Toggle comment**
# * `Shift+Alt+F` / `Shift+Option+F` - **Format SQL**
# * `Ctrl+Space` / `Cmd+Space` - **Trigger autocomplete**
#
# **Navigation:**
# * `Ctrl+F` / `Cmd+F` - Find in query
# * `Ctrl+H` / `Cmd+H` - Find and replace
# * `Ctrl+G` / `Cmd+G` - Go to line
#
# **Tab Management:**
# * `Ctrl+Alt+N` / `Cmd+Option+N` - **New tab**
# * `Ctrl+W` / `Cmd+W` - **Close tab**
# * `Ctrl+Tab` / `Cmd+Tab` - Next tab
# * `Ctrl+Shift+Tab` / `Cmd+Shift+Tab` - Previous tab
# * `Ctrl+1`, `Ctrl+2`, etc. - Go to specific tab
#
# **Selection:**
# * `Ctrl+A` / `Cmd+A` - Select all
# * `Ctrl+L` / `Cmd+L` - Select line
# * `Shift+Arrow` - Extend selection
#
# **Most important shortcuts:**
# 1. 🥇 `Ctrl+Enter` / `Cmd+Enter` - Run query
# 2. 🥈 `Ctrl+S` / `Cmd+S` - Save
# 3. 🥉 `Shift+Alt+F` / `Shift+Option+F` - Format
#
# ---
#
# **💡 Tip:** Print this reference and keep it handy until shortcuts become muscle memory!

# %% [markdown]
# ### 🔄 Common SQL Editor Workflows
#
# **Workflow 1: Exploratory Analysis**
# 1. 🔍 Search for table in Schema Browser
# 2. 👁️ View sample data and columns
# 3. ✍️ Write query with autocomplete
# 4. ⚡ Run with `LIMIT 10` to test
# 5. 📊 Examine results
# 6. 🔄 Iterate and refine
# 7. 💾 Save when satisfied
#
# **Workflow 2: Building a Report**
# 1. 📂 Create a folder for the project
# 2. 📑 Open multiple tabs for different metrics
# 3. ✍️ Write queries in each tab
# 4. ⚡ Run and verify each query
# 5. 📝 Add comments and documentation
# 6. 💾 Save all queries with descriptive names
# 7. ⭐ Star the main report query
#
# **Workflow 3: Debugging a Query**
# 1. 👁️ Review error message
# 2. 🔍 Check table/column names in Schema Browser
# 3. 🎯 Highlight and run parts of the query
# 4. 📝 Add comments to isolate the issue
# 5. 🔧 Fix the error
# 6. ⚡ Run again to verify
# 7. 💾 Save the corrected version
#
# **Workflow 4: Reusing Existing Queries**
# 1. 📜 Go to "Queries" → "My queries"
# 2. 🔍 Search for similar query
# 3. 📝 Open and review
# 4. 📝 Use "Save as" to create a copy
# 5. ✏️ Modify for new use case
# 6. 💾 Save with new name
#
# ---

# %% [markdown]
# ### 🌟 Additional SQL Editor Features
#
# Other useful features you should know about:
#
# **1. Query History Panel**
# * View execution history for current query
# * See past runs with timestamps
# * Compare execution times
# * Rerun previous versions
#
# **2. Schema Information**
# * Click table name in Schema Browser
# * View table properties
# * See table size and row count
# * Check last modified date
#
# **3. Full Screen Mode**
# * Click full screen icon (if available)
# * Maximize editor space
# * Hide sidebars for focus
# * Press `Esc` to exit
#
# **4. Dark/Light Theme**
# * User settings may have theme options
# * Choose based on preference
# * Reduces eye strain
#
# **5. Query Sharing**
# * Share queries with team members
# * Set permissions (view, edit, run)
# * Collaborate on analyses
# * (Covered in advanced topics)
#
# **6. Version History**
# * Some queries track version history
# * Restore previous versions if needed
# * See who made changes
# * (Covered in advanced topics)
#
# ---
#
# **💡 Note:** Some features may vary based on your Databricks workspace configuration

# %% [markdown]
# ## 📊 Quick Reference Card
#
# ### **Interface Components**
#
# | Component | Location | Purpose |
# |-----------|----------|----------|
# | Schema Browser | Left sidebar | Explore catalogs, schemas, tables |
# | Query Editor | Center panel | Write SQL code |
# | Results Panel | Below editor | View query results |
# | Warehouse Selector | Top-right | Choose compute resource |
# | Tab Bar | Top of editor | Manage multiple queries |
# | Save Button | Top-right | Save your work |
# | Run Button | Top-right | Execute query |
#
# ---
#
# ### **Essential Shortcuts**
#
# | Action | Windows/Linux | Mac |
# |--------|---------------|-----|
# | Run query | `Ctrl+Enter` | `Cmd+Enter` |
# | Save query | `Ctrl+S` | `Cmd+S` |
# | Format SQL | `Shift+Alt+F` | `Shift+Option+F` |
# | New tab | `Ctrl+Alt+N` | `Cmd+Option+N` |
# | Close tab | `Ctrl+W` | `Cmd+W` |
# | Comment line | `Ctrl+/` | `Cmd+/` |
# | Autocomplete | `Ctrl+Space` | `Cmd+Space` |
# | Find | `Ctrl+F` | `Cmd+F` |
#
# ---
#
# ### **Schema Browser Actions**
#
# * 👉 Expand/collapse - Click dropdown arrows
# * 👉 View table - Click table name
# * 👉 Insert table - Double-click or drag
# * 👉 Search - Click search icon
# * 👉 Refresh - Reload schema list
#
# ---
#
# ### **Query Editor Features**
#
# * ✨ Autocomplete - Suggests tables and columns
# * 🎨 Syntax highlighting - Color-coded SQL
# * ⚠️ Error detection - Red underlines
# * 📝 Formatting - Clean code layout
# * 💬 Comments - `--` and `/* */`
#
# ---
#
# ### **Tab Management**
#
# * ➕ Create - `+` button or `Ctrl+Alt+N`
# * 🔄 Switch - Click or `Ctrl+Tab`
# * ❌ Close - `X` or `Ctrl+W`
# * ✏️ Rename - Click tab name
#
# ---
#
# ### **Execution**
#
# * ▶️ Run all - Click Run or `Ctrl+Enter`
# * 🎯 Run selection - Highlight + `Ctrl+Enter`
# * ❌ Cancel - Click cancel button
# * 💾 Download - Export results
#
# ---

# %% [markdown]
# ## 🎯 Practice Exercise
#
# Put your new skills to the test!
#
# **Challenge:** Complete this workflow using only the SQL Editor interface:
#
# **Step 1: Explore**
# * Use Schema Browser to find `samples.tpch.customer`
# * View the columns and sample data
# * Note the column names
#
# **Step 2: Write**
# * Create a new tab
# * Write a query to find top 10 customers by account balance
# * Use autocomplete for table and column names
# * Add comments explaining the query
#
# **Step 3: Execute**
# * Format your SQL code
# * Run the query
# * View the results
#
# **Step 4: Save**
# * Save the query as "Top Customers by Balance"
# * Create a folder called "Practice"
# * Move the query into the folder
#
# **Step 5: Iterate**
# * Create a copy using "Save as"
# * Modify to show bottom 10 customers
# * Save as "Bottom Customers by Balance"
#
# **Bonus:**
# * Use only keyboard shortcuts (no mouse!)
# * Time yourself - how fast can you complete it?
#
# ---
#
# **💡 This exercise reinforces all the skills you learned!**

# %% [markdown]
# ## 🔧 Troubleshooting Common Issues
#
# **Issue 1: Autocomplete not working**
# * ✅ Try pressing `Ctrl+Space` / `Cmd+Space` manually
# * ✅ Check if you're connected to a warehouse
# * ✅ Refresh the page
#
# **Issue 2: Query won't run**
# * ✅ Check if warehouse is selected and running
# * ✅ Look for red underlines (syntax errors)
# * ✅ Verify table names are correct
# * ✅ Check permissions on the table
#
# **Issue 3: Can't find a table**
# * ✅ Use Schema Browser search
# * ✅ Check if you have access to that catalog
# * ✅ Verify table name spelling
# * ✅ Ask your admin about permissions
#
# **Issue 4: Results not showing**
# * ✅ Check if query returned 0 rows
# * ✅ Scroll down to see results panel
# * ✅ Expand results panel if collapsed
# * ✅ Check for error messages
#
# **Issue 5: Unsaved changes lost**
# * ✅ Save frequently with `Ctrl+S` / `Cmd+S`
# * ✅ Check for auto-saved drafts
# * ✅ Look in "Recent" queries
#
# **Issue 6: Slow performance**
# * ✅ Use LIMIT for testing
# * ✅ Check warehouse size
# * ✅ Optimize your query (add WHERE clauses)
# * ✅ Consider using a larger warehouse
#
# ---
#
# **💡 Tip:** Most issues are solved by refreshing the page or checking warehouse status

# %% [markdown]
# ## 🔎 What's Next?
#
# This demo covered the **SQL Editor interface**. Here are advanced topics for future learning:
#
# **Query-specific features (covered in other demos):**
# * 📊 Query parameters (widgets)
# * 📈 Visualizations and charts
# * 📊 Multiple statement results
# * 🔄 Query scheduling
# * 📧 Alerts and notifications
# * 📄 Query snippets
#
# **Collaboration features:**
# * 👥 Sharing queries with teams
# * 🔒 Permission management
# * 📝 Comments and discussions
# * 📊 Dashboard creation
#
# **Advanced topics:**
# * 🚀 Query optimization techniques
# * 📈 Performance tuning
# * 🔍 Query profiling
# * 📊 Warehouse configuration
# * 🔄 CI/CD for queries
#
# ---
#
# **These topics are covered in separate demos and courses!**

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed the Databricks SQL Editor interface guide!
#
# ### **What You Learned:**
#
# ✅ **Schema Browser** - Explore catalogs, schemas, tables, and columns
# ✅ **Query Editor** - Autocomplete, syntax highlighting, formatting
# ✅ **Tab Management** - Create, switch, close, and rename tabs
# ✅ **Query Execution** - Run queries, view results, monitor progress
# ✅ **Saving & Organizing** - Save queries, use folders, naming conventions
# ✅ **Keyboard Shortcuts** - Work efficiently with shortcuts
# ✅ **Best Practices** - Professional workflow tips
#
# ---
#
# ### **Key Takeaways:**
#
# 1. **Schema Browser is your friend** - Always explore data first
# 2. **Autocomplete saves time** - Use it for tables and columns
# 3. **Format your code** - Readable queries are maintainable queries
# 4. **Use tabs wisely** - Organize your work
# 5. **Save frequently** - Don't lose your work
# 6. **Master shortcuts** - `Ctrl+Enter`, `Ctrl+S`, `Shift+Alt+F`
# 7. **Name things well** - Future you will thank you
#
# ---
#
# ### **Your SQL Editor Workflow:**
#
# ```
# 1. 🔍 Explore data (Schema Browser)
#    ↓
# 2. ✍️ Write query (Autocomplete + Format)
#    ↓
# 3. ⚡ Run query (Ctrl+Enter)
#    ↓
# 4. 📊 Review results
#    ↓
# 5. 🔄 Iterate and refine
#    ↓
# 6. 💾 Save (Ctrl+S)
#    ↓
# 7. 📂 Organize (Folders)
# ```
#
# ---
#
# ### **Next Steps:**
#
# * Practice using the SQL Editor daily
# * Memorize the top 5 keyboard shortcuts
# * Organize your existing queries into folders
# * Explore advanced features (parameters, visualizations)
# * Share queries with your team
# * Build dashboards from your queries
#
# ---
#
# ### **Resources:**
#
# * [SQL Editor Documentation](https://docs.databricks.com/sql/user/queries/index.html)
# * [Databricks SQL Guide](https://docs.databricks.com/sql/index.html)
# * [Keyboard Shortcuts Reference](https://docs.databricks.com/sql/user/queries/keyboard-shortcuts.html)
#
# ---
#
# **You're now ready to work efficiently in the Databricks SQL Editor!** 🚀
#
# *Happy querying!*
